# %% [markdown]
# ## WeiPer on OpenOOD
# Set `dataset` to `cifar10` or `cifar100`
# and `postprocessor_name` to `weiper_density` to test WeiPer on CIFAR
# or `dataset`to `imagenet` to test WeiPer on ImageNet using ResNet50.
#
# Our method includes random perturbations and produces different results each time. To reduce the noise, set `iterations` to `5` or higher.
#
# ## Hyperparameters
# The hyperparameters can be set and found here:
# `./OpenOOD/configs/postprocessors/weiper_kldiv.yml`

# %%
# %load_ext autoreload
# %autoreload 2

from openood.networks import ResNet18_32x32
import torch
from openood.evaluation_api import Evaluator
from openood.preprocessors import BasePreprocessor
from tqdm import tqdm

from openood.networks import ResNet50
from torchvision.models import ResNet50_Weights
from torch.hub import load_state_dict_from_url

# %%
dataset = "cifar10"
models = [ResNet18_32x32(num_classes=100 if dataset=="cifar100" else 10)
          for _ in range(3)]
[model.load_state_dict(
    torch.load(f'./OpenOOD/results/{dataset}_resnet18_32x32_base_e100_lr0.1_default/s{i}/best.ckpt')
) for i,model in enumerate(models)]
# Out:
# /tmp/ipykernel_2652537/2904996973.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(f'./OpenOOD/results/{dataset}_resnet18_32x32_base_e100_lr0.1_default/s{i}/best.ckpt')
# [<All keys matched successfully>,
#  <All keys matched successfully>,
#  <All keys matched successfully>]

# %%
from functools import wraps

def batch_processing_decorator(batch_size):
    def decorator(forward_fn):
        @wraps(forward_fn)
        def wrapped_forward(x, *args, **kwargs):
            # Split the input tensor into smaller batches
            batched_input = torch.split(x, batch_size, dim=0)
            
            outputs = []
            # Instead of a single features list, we must handle the possibility
            # that we get a single tensor or a list of tensors for features.
            # We'll detect this on the first batch and then process accordingly.

            # These accumulators will be set after processing the first batch.
            # If features is a single tensor:
            #   features_single will hold the concatenation of these tensors
            # If features is a list of tensors:
            #   features_list_acc will be a list of lists, one for each layer.
            features_single = None
            features_list_acc = None
            is_feature_list = False

            first_batch = True

            for batch in tqdm(batched_input, disable=True):
                output = forward_fn(batch, *args, **kwargs)
                if isinstance(output, tuple):
                    # output can be (logits, feature) or (logits, feature_list)
                    logits = output[0]
                    feat = output[1]

                    outputs.append(logits.cpu())

                    if first_batch:
                        # Detect if feat is a tensor or a list
                        if isinstance(feat, torch.Tensor):
                            # single feature tensor
                            features_single = [feat.cpu()]
                            is_feature_list = False
                            print("[DEBUG] Detected single feature tensor in first batch")
                        elif isinstance(feat, list):
                            # list of features
                            is_feature_list = True
                            features_list_acc = [[] for _ in feat]
                            for i, f in enumerate(feat):
                                features_list_acc[i].append(f.cpu())
                            print("[DEBUG] Detected feature_list (multiple layers) in first batch")
                        else:
                            raise TypeError("[DEBUG] Unknown feature type returned by model.")
                        first_batch = False
                    else:
                        # subsequent batches
                        if is_feature_list:
                            # feat should be a list of tensors
                            if not isinstance(feat, list):
                                raise TypeError("[DEBUG] Inconsistent return type: expected list of tensors.")
                            if len(feat) != len(features_list_acc):
                                raise ValueError("[DEBUG] Layer count mismatch between batches.")
                            for i, f in enumerate(feat):
                                features_list_acc[i].append(f.cpu())
                        else:
                            # single tensor case
                            if not isinstance(feat, torch.Tensor):
                                raise TypeError("[DEBUG] Inconsistent return type: expected single tensor.")
                            features_single.append(feat.cpu())

                else:
                    # output is just logits
                    outputs.append(output.cpu())
                    # No features here
                    if first_batch:
                        # This would mean no features at all, which is not what we expect for OOD scoring.
                        # But let's just handle it gracefully.
                        features_single = None
                        features_list_acc = None
                        is_feature_list = False
                        first_batch = False

            final_output = torch.cat(outputs, dim=0)
            if is_feature_list:
                # concatenate each layer separately
                final_features = [torch.cat(layer_feats, dim=0) for layer_feats in features_list_acc]
                return final_output, final_features
            else:
                if features_single is not None:
                    final_features = torch.cat(features_single, dim=0)
                    return final_output, final_features
                else:
                    # No features returned at all scenario
                    return final_output
        return wrapped_forward
    return decorator

if dataset == 'imagenet':
    net = ResNet50()
    weights = ResNet50_Weights.IMAGENET1K_V1
    net.load_state_dict(load_state_dict_from_url(weights.url))
    
    net.forward =  batch_processing_decorator(batch_size=200)(net.forward)
    models = [net]
else:
    for m in models:
        m.forward = batch_processing_decorator(batch_size=200)(m.forward)

# %%
metrics = None
iterations = 1
for i in tqdm(range(iterations), disable=True):
    for j, model in enumerate(models):
        model.cuda()
        model.eval()

        evaluator = Evaluator(
            model, 
            id_name=dataset,
            data_root="./data",
            config_root="./OpenOOD/configs/",
            preprocessor=None, 
            postprocessor_name='weiper_kldiv', 
            batch_size=int(1e4),
            verbose=False, 
            APS_mode=False,
            num_workers=0,
        )
        evaluator.postprocessor.n_repeats = (
            100 if dataset == "cifar10" else 100
        )
        evaluator.eval_ood()
        if i == 0 and j == 0:
            metrics = evaluator.metrics["ood"]
            print(evaluator.postprocessor.get_hyperparam())
        else:
            metrics += evaluator.metrics["ood"] 
metrics/(len(models)*iterations)
# Out:
# [DEBUG] Initializing WeiPerKLDivPostprocessor with given configuration.
# [DEBUG] No layer_weights provided. Will use equal weighting (mean) if multiple layers are processed.
# [DEBUG] Entering WeiPerKLDivPostprocessor.setup
# [DEBUG] layer_names received: [1, 2, 3, 4]
# [DEBUG] final layer_names => [1, 2, 3, 4]
# [DEBUG] exact_minmax is True => computing penultimate min-max.
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] computed penultimate latents => ((0.0, 3.865647792816162), (-8.305510520935059, 17.728302001953125))
# [DEBUG] Building training densities for => [1, 2, 3, 4]
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] layer_train_info built for => [1, 2, 3, 'penultimate']
# [DEBUG] aggregator NPZ => id_scores_layer_1_2_3_4.npz
# [DEBUG] Found existing id_scores_layer_1_2_3_4.npz; loading aggregator ID data from it.
# [DEBUG] shape => (50000, 4)
# [DEBUG] aggregator fitting with shape => (50000, 4)
# [MDCDFAggregator] Fit: Storing 50000 ID vectors in 4-dim space.
# [MDCDFAggregator] KDE model fitted with params={'bandwidth': 0.5}
# [MDCDFAggregator] Example ID data stats => min: -6.638721466064453 max: -0.014022454619407654 mean: -4.2896
# [DEBUG] aggregator fit => method= kde
# [DEBUG] setup completed successfully.
# Performing inference on cifar10 test set...
#   0%|          | 0/1 [00:00<?, ?it/s]
# [DEBUG] Entering WeiPerKLDivPostprocessor.postprocess
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] postprocess layers_to_process: [1, 2, 3, 4]
# [DEBUG] postprocess at sample bidx=0/9000
# [DEBUG] postprocess at sample bidx=100/9000
# [DEBUG] postprocess at sample bidx=200/9000
# [DEBUG] postprocess at sample bidx=300/9000
# [DEBUG] postprocess at sample bidx=400/9000
# [DEBUG] postprocess at sample bidx=500/9000
# [DEBUG] postprocess at sample bidx=600/9000
# [DEBUG] postprocess at sample bidx=700/9000
# [DEBUG] postprocess at sample bidx=800/9000
# [DEBUG] postprocess at sample bidx=900/9000
# [DEBUG] postprocess at sample bidx=1000/9000
# [DEBUG] postprocess at sample bidx=1100/9000
# [DEBUG] postprocess at sample bidx=1200/9000
# [DEBUG] postprocess at sample bidx=1300/9000
# [DEBUG] postprocess at sample bidx=1400/9000
# [DEBUG] postprocess at sample bidx=1500/9000
# [DEBUG] postprocess at sample bidx=1600/9000
# [DEBUG] postprocess at sample bidx=1700/9000
# [DEBUG] postprocess at sample bidx=1800/9000
# [DEBUG] postprocess at sample bidx=1900/9000
# [DEBUG] postprocess at sample bidx=2000/9000
# [DEBUG] postprocess at sample bidx=2100/9000
# [DEBUG] postprocess at sample bidx=2200/9000
# [DEBUG] postprocess at sample bidx=2300/9000
# [DEBUG] postprocess at sample bidx=2400/9000
# [DEBUG] postprocess at sample bidx=2500/9000
# [DEBUG] postprocess at sample bidx=2600/9000
# [DEBUG] postprocess at sample bidx=2700/9000
# [DEBUG] postprocess at sample bidx=2800/9000
# [DEBUG] postprocess at sample bidx=2900/9000
# [DEBUG] postprocess at sample bidx=3000/9000
# [DEBUG] postprocess at sample bidx=3100/9000
# [DEBUG] postprocess at sample bidx=3200/9000
# [DEBUG] postprocess at sample bidx=3300/9000
# [DEBUG] postprocess at sample bidx=3400/9000
# [DEBUG] postprocess at sample bidx=3500/9000
# [DEBUG] postprocess at sample bidx=3600/9000
# [DEBUG] postprocess at sample bidx=3700/9000
# [DEBUG] postprocess at sample bidx=3800/9000
# [DEBUG] postprocess at sample bidx=3900/9000
# [DEBUG] postprocess at sample bidx=4000/9000
# [DEBUG] postprocess at sample bidx=4100/9000
# [DEBUG] postprocess at sample bidx=4200/9000
# [DEBUG] postprocess at sample bidx=4300/9000
# [DEBUG] postprocess at sample bidx=4400/9000
# [DEBUG] postprocess at sample bidx=4500/9000
# [DEBUG] postprocess at sample bidx=4600/9000
# [DEBUG] postprocess at sample bidx=4700/9000
# [DEBUG] postprocess at sample bidx=4800/9000
# [DEBUG] postprocess at sample bidx=4900/9000
# [DEBUG] postprocess at sample bidx=5000/9000
# [DEBUG] postprocess at sample bidx=5100/9000
# [DEBUG] postprocess at sample bidx=5200/9000
# [DEBUG] postprocess at sample bidx=5300/9000
# [DEBUG] postprocess at sample bidx=5400/9000
# [DEBUG] postprocess at sample bidx=5500/9000
# [DEBUG] postprocess at sample bidx=5600/9000
# [DEBUG] postprocess at sample bidx=5700/9000
# [DEBUG] postprocess at sample bidx=5800/9000
# [DEBUG] postprocess at sample bidx=5900/9000
# [DEBUG] postprocess at sample bidx=6000/9000
# [DEBUG] postprocess at sample bidx=6100/9000
# [DEBUG] postprocess at sample bidx=6200/9000
# [DEBUG] postprocess at sample bidx=6300/9000
# [DEBUG] postprocess at sample bidx=6400/9000
# [DEBUG] postprocess at sample bidx=6500/9000
# [DEBUG] postprocess at sample bidx=6600/9000
# [DEBUG] postprocess at sample bidx=6700/9000
# [DEBUG] postprocess at sample bidx=6800/9000
# [DEBUG] postprocess at sample bidx=6900/9000
# [DEBUG] postprocess at sample bidx=7000/9000
# [DEBUG] postprocess at sample bidx=7100/9000
# [DEBUG] postprocess at sample bidx=7200/9000
# [DEBUG] postprocess at sample bidx=7300/9000
# [DEBUG] postprocess at sample bidx=7400/9000
# [DEBUG] postprocess at sample bidx=7500/9000
# [DEBUG] postprocess at sample bidx=7600/9000
# [DEBUG] postprocess at sample bidx=7700/9000
# [DEBUG] postprocess at sample bidx=7800/9000
# [DEBUG] postprocess at sample bidx=7900/9000
# [DEBUG] postprocess at sample bidx=8000/9000
# [DEBUG] postprocess at sample bidx=8100/9000
# [DEBUG] postprocess at sample bidx=8200/9000
# [DEBUG] postprocess at sample bidx=8300/9000
# [DEBUG] postprocess at sample bidx=8400/9000
# [DEBUG] postprocess at sample bidx=8500/9000
# [DEBUG] postprocess at sample bidx=8600/9000
# [DEBUG] postprocess at sample bidx=8700/9000
# [DEBUG] postprocess at sample bidx=8800/9000
# [DEBUG] postprocess at sample bidx=8900/9000
# Scoring process: 100%|██████████| 9000/9000 [19:16<00:00,  7.78it/s]
# [DEBUG] Using aggregator => passing multi-dim score to aggregator.
# [MDCDFAggregator] score() called on shape (9000, 4)
# [MDCDFAggregator] first row => [-5.04700232 -5.65345764 -6.472332   -0.02097563]
# [MDCDFAggregator] first aggregator output => 0.51086
# [DEBUG] final aggregator shape => torch.Size([9000])
# 100%|██████████| 1/1 [23:46<00:00, 1426.40s/it]
# Processing near ood...
# Performing inference on cifar100 dataset...
#   0%|          | 0/1 [00:00<?, ?it/s]
# [DEBUG] Entering WeiPerKLDivPostprocessor.postprocess
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] postprocess layers_to_process: [1, 2, 3, 4]
# [DEBUG] postprocess at sample bidx=0/9000
# [DEBUG] postprocess at sample bidx=100/9000
# [DEBUG] postprocess at sample bidx=200/9000
# [DEBUG] postprocess at sample bidx=300/9000
# [DEBUG] postprocess at sample bidx=400/9000
# [DEBUG] postprocess at sample bidx=500/9000
# [DEBUG] postprocess at sample bidx=600/9000
# [DEBUG] postprocess at sample bidx=700/9000
# [DEBUG] postprocess at sample bidx=800/9000
# [DEBUG] postprocess at sample bidx=900/9000
# [DEBUG] postprocess at sample bidx=1000/9000
# [DEBUG] postprocess at sample bidx=1100/9000
# [DEBUG] postprocess at sample bidx=1200/9000
# [DEBUG] postprocess at sample bidx=1300/9000
# [DEBUG] postprocess at sample bidx=1400/9000
# [DEBUG] postprocess at sample bidx=1500/9000
# [DEBUG] postprocess at sample bidx=1600/9000
# [DEBUG] postprocess at sample bidx=1700/9000
# [DEBUG] postprocess at sample bidx=1800/9000
# [DEBUG] postprocess at sample bidx=1900/9000
# [DEBUG] postprocess at sample bidx=2000/9000
# [DEBUG] postprocess at sample bidx=2100/9000
# [DEBUG] postprocess at sample bidx=2200/9000
# [DEBUG] postprocess at sample bidx=2300/9000
# [DEBUG] postprocess at sample bidx=2400/9000
# [DEBUG] postprocess at sample bidx=2500/9000
# [DEBUG] postprocess at sample bidx=2600/9000
# [DEBUG] postprocess at sample bidx=2700/9000
# [DEBUG] postprocess at sample bidx=2800/9000
# [DEBUG] postprocess at sample bidx=2900/9000
# [DEBUG] postprocess at sample bidx=3000/9000
# [DEBUG] postprocess at sample bidx=3100/9000
# [DEBUG] postprocess at sample bidx=3200/9000
# [DEBUG] postprocess at sample bidx=3300/9000
# [DEBUG] postprocess at sample bidx=3400/9000
# [DEBUG] postprocess at sample bidx=3500/9000
# [DEBUG] postprocess at sample bidx=3600/9000
# [DEBUG] postprocess at sample bidx=3700/9000
# [DEBUG] postprocess at sample bidx=3800/9000
# [DEBUG] postprocess at sample bidx=3900/9000
# [DEBUG] postprocess at sample bidx=4000/9000
# [DEBUG] postprocess at sample bidx=4100/9000
# [DEBUG] postprocess at sample bidx=4200/9000
# [DEBUG] postprocess at sample bidx=4300/9000
# [DEBUG] postprocess at sample bidx=4400/9000
# [DEBUG] postprocess at sample bidx=4500/9000
# [DEBUG] postprocess at sample bidx=4600/9000
# [DEBUG] postprocess at sample bidx=4700/9000
# [DEBUG] postprocess at sample bidx=4800/9000
# [DEBUG] postprocess at sample bidx=4900/9000
# [DEBUG] postprocess at sample bidx=5000/9000
# [DEBUG] postprocess at sample bidx=5100/9000
# [DEBUG] postprocess at sample bidx=5200/9000
# [DEBUG] postprocess at sample bidx=5300/9000
# [DEBUG] postprocess at sample bidx=5400/9000
# [DEBUG] postprocess at sample bidx=5500/9000
# [DEBUG] postprocess at sample bidx=5600/9000
# [DEBUG] postprocess at sample bidx=5700/9000
# [DEBUG] postprocess at sample bidx=5800/9000
# [DEBUG] postprocess at sample bidx=5900/9000
# [DEBUG] postprocess at sample bidx=6000/9000
# [DEBUG] postprocess at sample bidx=6100/9000
# [DEBUG] postprocess at sample bidx=6200/9000
# [DEBUG] postprocess at sample bidx=6300/9000
# [DEBUG] postprocess at sample bidx=6400/9000
# [DEBUG] postprocess at sample bidx=6500/9000
# [DEBUG] postprocess at sample bidx=6600/9000
# [DEBUG] postprocess at sample bidx=6700/9000
# [DEBUG] postprocess at sample bidx=6800/9000
# [DEBUG] postprocess at sample bidx=6900/9000
# [DEBUG] postprocess at sample bidx=7000/9000
# [DEBUG] postprocess at sample bidx=7100/9000
# [DEBUG] postprocess at sample bidx=7200/9000
# [DEBUG] postprocess at sample bidx=7300/9000
# [DEBUG] postprocess at sample bidx=7400/9000
# [DEBUG] postprocess at sample bidx=7500/9000
# [DEBUG] postprocess at sample bidx=7600/9000
# [DEBUG] postprocess at sample bidx=7700/9000
# [DEBUG] postprocess at sample bidx=7800/9000
# [DEBUG] postprocess at sample bidx=7900/9000
# [DEBUG] postprocess at sample bidx=8000/9000
# [DEBUG] postprocess at sample bidx=8100/9000
# [DEBUG] postprocess at sample bidx=8200/9000
# [DEBUG] postprocess at sample bidx=8300/9000
# [DEBUG] postprocess at sample bidx=8400/9000
# [DEBUG] postprocess at sample bidx=8500/9000
# [DEBUG] postprocess at sample bidx=8600/9000
# [DEBUG] postprocess at sample bidx=8700/9000
# [DEBUG] postprocess at sample bidx=8800/9000
# [DEBUG] postprocess at sample bidx=8900/9000
# Scoring process: 100%|██████████| 9000/9000 [18:57<00:00,  7.91it/s]
# [DEBUG] Using aggregator => passing multi-dim score to aggregator.
# [MDCDFAggregator] score() called on shape (9000, 4)
# [MDCDFAggregator] first row => [-4.97512674 -5.62187672 -6.44151783 -0.27272725]
# [MDCDFAggregator] first aggregator output => 0.01406
# [DEBUG] final aggregator shape => torch.Size([9000])
# 100%|██████████| 1/1 [23:39<00:00, 1419.66s/it]
# Computing metrics on cifar100 dataset...
# FPR@95: 68.46, AUROC: 84.01 AUPR_IN: 84.17, AUPR_OUT: 81.24
# ──────────────────────────────────────────────────────────────────────
#
# Computing mean metrics...
# FPR@95: 68.46, AUROC: 84.01 AUPR_IN: 84.17, AUPR_OUT: 81.24
# ──────────────────────────────────────────────────────────────────────
# ID Acc Eval: 100%|██████████| 1/1 [00:29<00:00, 29.16s/it]
#           FPR@95  AUROC  AUPR_IN  AUPR_OUT   ACC
# cifar100   68.46  84.01    84.17     81.24 95.22
# nearood    68.46  84.01    84.17     81.24 95.22
# (2.5, 0.1, 4, 15, 100, 1.8)
# [DEBUG] Initializing WeiPerKLDivPostprocessor with given configuration.
# [DEBUG] No layer_weights provided. Will use equal weighting (mean) if multiple layers are processed.
# [DEBUG] Entering WeiPerKLDivPostprocessor.setup
# [DEBUG] layer_names received: [1, 2, 3, 4]
# [DEBUG] final layer_names => [1, 2, 3, 4]
# [DEBUG] exact_minmax is True => computing penultimate min-max.
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       5 model.cuda()
#       6 model.eval()
# ----> 8 evaluator = Evaluator(
#       9     model,
#      10     id_name=dataset,
#      11     data_root="./data",
#      12     config_root="./OpenOOD/configs/",
#      13     preprocessor=None,
#      14     postprocessor_name='weiper_kldiv',
#      15     batch_size=int(1e4),
#      16     verbose=False,
#      17     APS_mode=False,
#      18     num_workers=0,
#      19 )
#      20 evaluator.postprocessor.n_repeats = (
#      21     100 if dataset == "cifar10" else 100
#      22 )
#      23 evaluator.eval_ood()
#
# File /media/dc-04-vol03/omar/Bachelor/weiper/Weiper/OpenOOD/openood/evaluation_api/evaluator.py:105, in Evaluator.__init__(self, net, id_name, data_root, config_root, preprocessor, postprocessor_name, postprocessor, batch_size, shuffle, num_workers, cached_dir, use_cache, APS_mode, verbose, **postpc_kwargs)
#      96     postprocessor.setup(
#      97         net,
#      98         dataloader_dict["id"],
#    (...)
#     102         **postpc_kwargs,
#     103     )
#     104 else:
# --> 105     postprocessor.setup(net, dataloader_dict["id"], dataloader_dict["ood"])
#     107 self.id_name = id_name
#     108 self.net = net
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /media/dc-04-vol03/omar/Bachelor/weiper/Weiper/OpenOOD/openood/postprocessors/weiper_kldiv_postprocessor.py:106, in WeiPerKLDivPostprocessor.setup(self, net, id_loader_dict, ood_loader_dict, id_name, valid_num, layer_names, layer_weights, aps, use_cache, hyperparameter_search, latents_loader, **kwargs)
#     104 if self.exact_minmax:
#     105     print("[DEBUG] exact_minmax is True => computing penultimate min-max.")
# --> 106     for i, batch in enumerate(train_dl):
#     107         data = batch["data"].to(device)
#     108         output, feat_list = net(data, return_feature_list=True)
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torch/utils/data/dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File /media/dc-04-vol03/omar/Bachelor/weiper/Weiper/OpenOOD/openood/datasets/base_dataset.py:31, in BaseDataset.__getitem__(self, index)
#      29 while True:
#      30     try:
# ---> 31         sample = self.getitem(index)
#      32         break
#      33     except Exception as e:
#
# File /media/dc-04-vol03/omar/Bachelor/weiper/Weiper/OpenOOD/openood/datasets/imglist_dataset.py:85, in ImglistDataset.getitem(self, index)
#      83     image = Image.open(buff).convert('RGB')
#      84     sample['data'] = self.transform_image(image)
# ---> 85     sample['data_aux'] = self.transform_aux_image(image)
#      86 extras = ast.literal_eval(extra_str)
#      87 try:
#
# File /media/dc-04-vol03/omar/Bachelor/weiper/Weiper/OpenOOD/openood/preprocessors/base_preprocessor.py:56, in BasePreprocessor.__call__(self, image)
#      55 def __call__(self, image):
# ---> 56     return self.transform(image)
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torchvision/transforms/transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)
#     135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torchvision/transforms/functional.py:176, in to_tensor(pic)
#     174 img = img.permute((2, 0, 1)).contiguous()
#     175 if isinstance(img, torch.ByteTensor):
# --> 176     return img.to(dtype=default_float_dtype).div(255)
#     177 else:
#     178     return img
#
# KeyboardInterrupt:
