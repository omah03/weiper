# %% [markdown]
# ## WeiPer on OpenOOD
# Set `dataset` to `cifar10` or `cifar100`
# and `postprocessor_name` to `weiper_density` to test WeiPer on CIFAR
# or `dataset`to `imagenet` to test WeiPer on ImageNet using ResNet50.
#
# Our method includes random perturbations and produces different results each time. To reduce the noise, set `iterations` to `5` or higher.
#
# ## Hyperparameters
# The hyperparameters can be set and found here:
# `./OpenOOD/configs/postprocessors/weiper_kldiv.yml`

# %%
# %load_ext autoreload
# %autoreload 2

from openood.networks import ResNet18_32x32
import torch
from openood.evaluation_api import Evaluator
from openood.preprocessors import BasePreprocessor
from tqdm import tqdm

from openood.networks import ResNet50
from torchvision.models import ResNet50_Weights
from torch.hub import load_state_dict_from_url

# %%
dataset = "cifar10"
models = [ResNet18_32x32(num_classes=100 if dataset=="cifar100" else 10)
          for _ in range(3)]
[model.load_state_dict(
    torch.load(f'./OpenOOD/results/{dataset}_resnet18_32x32_base_e100_lr0.1_default/s{i}/best.ckpt')
) for i,model in enumerate(models)]
# Out:
# /tmp/ipykernel_2718361/2904996973.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(f'./OpenOOD/results/{dataset}_resnet18_32x32_base_e100_lr0.1_default/s{i}/best.ckpt')
# [<All keys matched successfully>,
#  <All keys matched successfully>,
#  <All keys matched successfully>]

# %%
from functools import wraps

def batch_processing_decorator(batch_size):
    def decorator(forward_fn):
        @wraps(forward_fn)
        def wrapped_forward(x, *args, **kwargs):
            # Split the input tensor into smaller batches
            batched_input = torch.split(x, batch_size, dim=0)
            
            outputs = []
            # Instead of a single features list, we must handle the possibility
            # that we get a single tensor or a list of tensors for features.
            # We'll detect this on the first batch and then process accordingly.

            # These accumulators will be set after processing the first batch.
            # If features is a single tensor:
            #   features_single will hold the concatenation of these tensors
            # If features is a list of tensors:
            #   features_list_acc will be a list of lists, one for each layer.
            features_single = None
            features_list_acc = None
            is_feature_list = False

            first_batch = True

            for batch in tqdm(batched_input, disable=True):
                output = forward_fn(batch, *args, **kwargs)
                if isinstance(output, tuple):
                    # output can be (logits, feature) or (logits, feature_list)
                    logits = output[0]
                    feat = output[1]

                    outputs.append(logits.cpu())

                    if first_batch:
                        # Detect if feat is a tensor or a list
                        if isinstance(feat, torch.Tensor):
                            # single feature tensor
                            features_single = [feat.cpu()]
                            is_feature_list = False
                            print("[DEBUG] Detected single feature tensor in first batch")
                        elif isinstance(feat, list):
                            # list of features
                            is_feature_list = True
                            features_list_acc = [[] for _ in feat]
                            for i, f in enumerate(feat):
                                features_list_acc[i].append(f.cpu())
                            print("[DEBUG] Detected feature_list (multiple layers) in first batch")
                        else:
                            raise TypeError("[DEBUG] Unknown feature type returned by model.")
                        first_batch = False
                    else:
                        # subsequent batches
                        if is_feature_list:
                            # feat should be a list of tensors
                            if not isinstance(feat, list):
                                raise TypeError("[DEBUG] Inconsistent return type: expected list of tensors.")
                            if len(feat) != len(features_list_acc):
                                raise ValueError("[DEBUG] Layer count mismatch between batches.")
                            for i, f in enumerate(feat):
                                features_list_acc[i].append(f.cpu())
                        else:
                            # single tensor case
                            if not isinstance(feat, torch.Tensor):
                                raise TypeError("[DEBUG] Inconsistent return type: expected single tensor.")
                            features_single.append(feat.cpu())

                else:
                    # output is just logits
                    outputs.append(output.cpu())
                    # No features here
                    if first_batch:
                        # This would mean no features at all, which is not what we expect for OOD scoring.
                        # But let's just handle it gracefully.
                        features_single = None
                        features_list_acc = None
                        is_feature_list = False
                        first_batch = False

            final_output = torch.cat(outputs, dim=0)
            if is_feature_list:
                # concatenate each layer separately
                final_features = [torch.cat(layer_feats, dim=0) for layer_feats in features_list_acc]
                return final_output, final_features
            else:
                if features_single is not None:
                    final_features = torch.cat(features_single, dim=0)
                    return final_output, final_features
                else:
                    # No features returned at all scenario
                    return final_output
        return wrapped_forward
    return decorator

if dataset == 'imagenet':
    net = ResNet50()
    weights = ResNet50_Weights.IMAGENET1K_V1
    net.load_state_dict(load_state_dict_from_url(weights.url))
    
    net.forward =  batch_processing_decorator(batch_size=200)(net.forward)
    models = [net]
else:
    for m in models:
        m.forward = batch_processing_decorator(batch_size=200)(m.forward)

# %%
metrics = None
iterations = 1
for i in tqdm(range(iterations), disable=True):
    for j, model in enumerate(models):
        model.cuda()
        model.eval()

        evaluator = Evaluator(
            model, 
            id_name=dataset,
            data_root="./data",
            config_root="./OpenOOD/configs/",
            preprocessor=None, 
            postprocessor_name='weiper_kldiv', 
            batch_size=int(1e4),
            verbose=False, 
            APS_mode=False,
            num_workers=0,
        )
        evaluator.postprocessor.n_repeats = (
            100 if dataset == "cifar10" else 100
        )
        evaluator.eval_ood()
        if i == 0 and j == 0:
            metrics = evaluator.metrics["ood"]
            print(evaluator.postprocessor.get_hyperparam())
        else:
            metrics += evaluator.metrics["ood"] 
metrics/(len(models)*iterations)
# Out:
# [DEBUG] aggregator_mode=none => no layer_weights (default mean if multi-layers).
# [DEBUG] WeiPerKLDivPostprocessor constructed. aggregator_mode=none
#         layer_names: [4]
#
# [DEBUG] Entering WeiPerKLDivPostprocessor.setup
# [DEBUG] aggregator_mode='none' & single-layer=[4] => single-layer penultimate approach.
# [DEBUG] _setup_singlelayer_original => single-layer penultimate logic.
# [DEBUG] Detected single feature tensor in first batch
# [DEBUG]  Perturb 0 => avg norm 10.00000
# [DEBUG]  Perturb 1 => avg norm 10.00000
# [DEBUG]  Perturb 2 => avg norm 10.00000
# [DEBUG]  Perturb 3 => avg norm 10.00000
# [DEBUG]  Perturb 4 => avg norm 10.00000
# [DEBUG]  Perturb 5 => avg norm 10.00000
# [DEBUG]  Perturb 6 => avg norm 10.00000
# [DEBUG]  Perturb 7 => avg norm 10.00000
# [DEBUG]  Perturb 8 => avg norm 10.00000
# [DEBUG]  Perturb 9 => avg norm 10.00000
# [DEBUG]  Perturb 10 => avg norm 10.00000
# [DEBUG]  Perturb 11 => avg norm 10.00000
# [DEBUG]  Perturb 12 => avg norm 10.00000
# [DEBUG]  Perturb 13 => avg norm 10.00000
# [DEBUG]  Perturb 14 => avg norm 10.00000
# [DEBUG]  Perturb 15 => avg norm 10.00000
# [DEBUG]  Perturb 16 => avg norm 10.00000
# [DEBUG]  Perturb 17 => avg norm 10.00000
# [DEBUG]  Perturb 18 => avg norm 10.00000
# [DEBUG]  Perturb 19 => avg norm 10.00000
# [DEBUG]  Perturb 20 => avg norm 10.00000
# [DEBUG]  Perturb 21 => avg norm 10.00000
# [DEBUG]  Perturb 22 => avg norm 10.00000
# [DEBUG]  Perturb 23 => avg norm 10.00000
# [DEBUG]  Perturb 24 => avg norm 10.00000
# [DEBUG]  Perturb 25 => avg norm 10.00000
# [DEBUG]  Perturb 26 => avg norm 10.00000
# [DEBUG]  Perturb 27 => avg norm 10.00000
# [DEBUG]  Perturb 28 => avg norm 10.00000
# [DEBUG]  Perturb 29 => avg norm 10.00000
# [DEBUG]  Perturb 30 => avg norm 10.00000
# [DEBUG]  Perturb 31 => avg norm 10.00000
# [DEBUG]  Perturb 32 => avg norm 10.00000
# [DEBUG]  Perturb 33 => avg norm 10.00000
# [DEBUG]  Perturb 34 => avg norm 10.00000
# [DEBUG]  Perturb 35 => avg norm 10.00000
# [DEBUG]  Perturb 36 => avg norm 10.00000
# [DEBUG]  Perturb 37 => avg norm 10.00000
# [DEBUG]  Perturb 38 => avg norm 10.00000
# [DEBUG]  Perturb 39 => avg norm 10.00000
# [DEBUG]  Perturb 40 => avg norm 10.00000
# [DEBUG]  Perturb 41 => avg norm 10.00000
# [DEBUG]  Perturb 42 => avg norm 10.00000
# [DEBUG]  Perturb 43 => avg norm 10.00000
# [DEBUG]  Perturb 44 => avg norm 10.00000
# [DEBUG]  Perturb 45 => avg norm 10.00000
# [DEBUG]  Perturb 46 => avg norm 10.00000
# [DEBUG]  Perturb 47 => avg norm 10.00000
# [DEBUG]  Perturb 48 => avg norm 10.00000
# [DEBUG]  Perturb 49 => avg norm 10.00000
# [DEBUG]  Perturb 50 => avg norm 10.00000
# [DEBUG]  Perturb 51 => avg norm 10.00000
# [DEBUG]  Perturb 52 => avg norm 10.00000
# [DEBUG]  Perturb 53 => avg norm 10.00000
# [DEBUG]  Perturb 54 => avg norm 10.00000
# [DEBUG]  Perturb 55 => avg norm 10.00000
# [DEBUG]  Perturb 56 => avg norm 10.00000
# [DEBUG]  Perturb 57 => avg norm 10.00000
# [DEBUG]  Perturb 58 => avg norm 10.00000
# [DEBUG]  Perturb 59 => avg norm 10.00000
# [DEBUG]  Perturb 60 => avg norm 10.00000
# [DEBUG]  Perturb 61 => avg norm 10.00000
# [DEBUG]  Perturb 62 => avg norm 10.00000
# [DEBUG]  Perturb 63 => avg norm 10.00000
# [DEBUG]  Perturb 64 => avg norm 10.00000
# [DEBUG]  Perturb 65 => avg norm 10.00000
# [DEBUG]  Perturb 66 => avg norm 10.00000
# [DEBUG]  Perturb 67 => avg norm 10.00000
# [DEBUG]  Perturb 68 => avg norm 10.00000
# [DEBUG]  Perturb 69 => avg norm 10.00000
# [DEBUG]  Perturb 70 => avg norm 10.00000
# [DEBUG]  Perturb 71 => avg norm 10.00000
# [DEBUG]  Perturb 72 => avg norm 10.00000
# [DEBUG]  Perturb 73 => avg norm 10.00000
# [DEBUG]  Perturb 74 => avg norm 10.00000
# [DEBUG]  Perturb 75 => avg norm 10.00000
# [DEBUG]  Perturb 76 => avg norm 10.00000
# [DEBUG]  Perturb 77 => avg norm 10.00000
# [DEBUG]  Perturb 78 => avg norm 10.00000
# [DEBUG]  Perturb 79 => avg norm 10.00000
# [DEBUG]  Perturb 80 => avg norm 10.00000
# [DEBUG]  Perturb 81 => avg norm 10.00000
# [DEBUG]  Perturb 82 => avg norm 10.00000
# [DEBUG]  Perturb 83 => avg norm 10.00000
# [DEBUG]  Perturb 84 => avg norm 10.00000
# [DEBUG]  Perturb 85 => avg norm 10.00000
# [DEBUG]  Perturb 86 => avg norm 10.00000
# [DEBUG]  Perturb 87 => avg norm 10.00000
# [DEBUG]  Perturb 88 => avg norm 10.00000
# [DEBUG]  Perturb 89 => avg norm 10.00000
# [DEBUG]  Perturb 90 => avg norm 10.00000
# [DEBUG]  Perturb 91 => avg norm 10.00000
# [DEBUG]  Perturb 92 => avg norm 10.00000
# [DEBUG]  Perturb 93 => avg norm 10.00000
# [DEBUG]  Perturb 94 => avg norm 10.00000
# [DEBUG]  Perturb 95 => avg norm 10.00000
# [DEBUG]  Perturb 96 => avg norm 10.00000
# [DEBUG]  Perturb 97 => avg norm 10.00000
# [DEBUG]  Perturb 98 => avg norm 10.00000
# [DEBUG]  Perturb 99 => avg norm 10.00000
# [DEBUG] WeiPer average noise norm => 10.00000
# [DEBUG] Detected single feature tensor in first batch
# [DEBUG]  Perturb 0 => avg norm 10.00000
# [DEBUG]  Perturb 1 => avg norm 10.00000
# [DEBUG]  Perturb 2 => avg norm 10.00000
# [DEBUG]  Perturb 3 => avg norm 10.00000
# [DEBUG]  Perturb 4 => avg norm 10.00000
# [DEBUG]  Perturb 5 => avg norm 10.00000
# [DEBUG]  Perturb 6 => avg norm 10.00000
# [DEBUG]  Perturb 7 => avg norm 10.00000
# [DEBUG]  Perturb 8 => avg norm 10.00000
# [DEBUG]  Perturb 9 => avg norm 10.00000
# [DEBUG]  Perturb 10 => avg norm 10.00000
# [DEBUG]  Perturb 11 => avg norm 10.00000
# [DEBUG]  Perturb 12 => avg norm 10.00000
# [DEBUG]  Perturb 13 => avg norm 10.00000
# [DEBUG]  Perturb 14 => avg norm 10.00000
# [DEBUG]  Perturb 15 => avg norm 10.00000
# [DEBUG]  Perturb 16 => avg norm 10.00000
# [DEBUG]  Perturb 17 => avg norm 10.00000
# [DEBUG]  Perturb 18 => avg norm 10.00000
# [DEBUG]  Perturb 19 => avg norm 10.00000
# [DEBUG]  Perturb 20 => avg norm 10.00000
# [DEBUG]  Perturb 21 => avg norm 10.00000
# [DEBUG]  Perturb 22 => avg norm 10.00000
# [DEBUG]  Perturb 23 => avg norm 10.00000
# [DEBUG]  Perturb 24 => avg norm 10.00000
# [DEBUG]  Perturb 25 => avg norm 10.00000
# [DEBUG]  Perturb 26 => avg norm 10.00000
# [DEBUG]  Perturb 27 => avg norm 10.00000
# [DEBUG]  Perturb 28 => avg norm 10.00000
# [DEBUG]  Perturb 29 => avg norm 10.00000
# [DEBUG]  Perturb 30 => avg norm 10.00000
# [DEBUG]  Perturb 31 => avg norm 10.00000
# [DEBUG]  Perturb 32 => avg norm 10.00000
# [DEBUG]  Perturb 33 => avg norm 10.00000
# [DEBUG]  Perturb 34 => avg norm 10.00000
# [DEBUG]  Perturb 35 => avg norm 10.00000
# [DEBUG]  Perturb 36 => avg norm 10.00000
# [DEBUG]  Perturb 37 => avg norm 10.00000
# [DEBUG]  Perturb 38 => avg norm 10.00000
# [DEBUG]  Perturb 39 => avg norm 10.00000
# [DEBUG]  Perturb 40 => avg norm 10.00000
# [DEBUG]  Perturb 41 => avg norm 10.00000
# [DEBUG]  Perturb 42 => avg norm 10.00000
# [DEBUG]  Perturb 43 => avg norm 10.00000
# [DEBUG]  Perturb 44 => avg norm 10.00000
# [DEBUG]  Perturb 45 => avg norm 10.00000
# [DEBUG]  Perturb 46 => avg norm 10.00000
# [DEBUG]  Perturb 47 => avg norm 10.00000
# [DEBUG]  Perturb 48 => avg norm 10.00000
# [DEBUG]  Perturb 49 => avg norm 10.00000
# [DEBUG]  Perturb 50 => avg norm 10.00000
# [DEBUG]  Perturb 51 => avg norm 10.00000
# [DEBUG]  Perturb 52 => avg norm 10.00000
# [DEBUG]  Perturb 53 => avg norm 10.00000
# [DEBUG]  Perturb 54 => avg norm 10.00000
# [DEBUG]  Perturb 55 => avg norm 10.00000
# [DEBUG]  Perturb 56 => avg norm 10.00000
# [DEBUG]  Perturb 57 => avg norm 10.00000
# [DEBUG]  Perturb 58 => avg norm 10.00000
# [DEBUG]  Perturb 59 => avg norm 10.00000
# [DEBUG]  Perturb 60 => avg norm 10.00000
# [DEBUG]  Perturb 61 => avg norm 10.00000
# [DEBUG]  Perturb 62 => avg norm 10.00000
# [DEBUG]  Perturb 63 => avg norm 10.00000
# [DEBUG]  Perturb 64 => avg norm 10.00000
# [DEBUG]  Perturb 65 => avg norm 10.00000
# [DEBUG]  Perturb 66 => avg norm 10.00000
# [DEBUG]  Perturb 67 => avg norm 10.00000
# [DEBUG]  Perturb 68 => avg norm 10.00000
# [DEBUG]  Perturb 69 => avg norm 10.00000
# [DEBUG]  Perturb 70 => avg norm 10.00000
# [DEBUG]  Perturb 71 => avg norm 10.00000
# [DEBUG]  Perturb 72 => avg norm 10.00000
# [DEBUG]  Perturb 73 => avg norm 10.00000
# [DEBUG]  Perturb 74 => avg norm 10.00000
# [DEBUG]  Perturb 75 => avg norm 10.00000
# [DEBUG]  Perturb 76 => avg norm 10.00000
# [DEBUG]  Perturb 77 => avg norm 10.00000
# [DEBUG]  Perturb 78 => avg norm 10.00000
# [DEBUG]  Perturb 79 => avg norm 10.00000
# [DEBUG]  Perturb 80 => avg norm 10.00000
# [DEBUG]  Perturb 81 => avg norm 10.00000
# [DEBUG]  Perturb 82 => avg norm 10.00000
# [DEBUG]  Perturb 83 => avg norm 10.00000
# [DEBUG]  Perturb 84 => avg norm 10.00000
# [DEBUG]  Perturb 85 => avg norm 10.00000
# [DEBUG]  Perturb 86 => avg norm 10.00000
# [DEBUG]  Perturb 87 => avg norm 10.00000
# [DEBUG]  Perturb 88 => avg norm 10.00000
# [DEBUG]  Perturb 89 => avg norm 10.00000
# [DEBUG]  Perturb 90 => avg norm 10.00000
# [DEBUG]  Perturb 91 => avg norm 10.00000
# [DEBUG]  Perturb 92 => avg norm 10.00000
# [DEBUG]  Perturb 93 => avg norm 10.00000
# [DEBUG]  Perturb 94 => avg norm 10.00000
# [DEBUG]  Perturb 95 => avg norm 10.00000
# [DEBUG]  Perturb 96 => avg norm 10.00000
# [DEBUG]  Perturb 97 => avg norm 10.00000
# [DEBUG]  Perturb 98 => avg norm 10.00000
# [DEBUG]  Perturb 99 => avg norm 10.00000
# [DEBUG] WeiPer average noise norm => 10.00000
# [DEBUG] Detected single feature tensor in first batch
# [DEBUG]  Perturb 0 => avg norm 10.00000
# [DEBUG]  Perturb 1 => avg norm 10.00000
# [DEBUG]  Perturb 2 => avg norm 10.00000
# [DEBUG]  Perturb 3 => avg norm 10.00000
# [DEBUG]  Perturb 4 => avg norm 10.00000
# [DEBUG]  Perturb 5 => avg norm 10.00000
# [DEBUG]  Perturb 6 => avg norm 10.00000
# [DEBUG]  Perturb 7 => avg norm 10.00000
# [DEBUG]  Perturb 8 => avg norm 10.00000
# [DEBUG]  Perturb 9 => avg norm 10.00000
# [DEBUG]  Perturb 10 => avg norm 10.00000
# [DEBUG]  Perturb 11 => avg norm 10.00000
# [DEBUG]  Perturb 12 => avg norm 10.00000
# [DEBUG]  Perturb 13 => avg norm 10.00000
# [DEBUG]  Perturb 14 => avg norm 10.00000
# [DEBUG]  Perturb 15 => avg norm 10.00000
# [DEBUG]  Perturb 16 => avg norm 10.00000
# [DEBUG]  Perturb 17 => avg norm 10.00000
# [DEBUG]  Perturb 18 => avg norm 10.00000
# [DEBUG]  Perturb 19 => avg norm 10.00000
# [DEBUG]  Perturb 20 => avg norm 10.00000
# [DEBUG]  Perturb 21 => avg norm 10.00000
# [DEBUG]  Perturb 22 => avg norm 10.00000
# [DEBUG]  Perturb 23 => avg norm 10.00000
# [DEBUG]  Perturb 24 => avg norm 10.00000
# [DEBUG]  Perturb 25 => avg norm 10.00000
# [DEBUG]  Perturb 26 => avg norm 10.00000
# [DEBUG]  Perturb 27 => avg norm 10.00000
# [DEBUG]  Perturb 28 => avg norm 10.00000
# [DEBUG]  Perturb 29 => avg norm 10.00000
# [DEBUG]  Perturb 30 => avg norm 10.00000
# [DEBUG]  Perturb 31 => avg norm 10.00000
# [DEBUG]  Perturb 32 => avg norm 10.00000
# [DEBUG]  Perturb 33 => avg norm 10.00000
# [DEBUG]  Perturb 34 => avg norm 10.00000
# [DEBUG]  Perturb 35 => avg norm 10.00000
# [DEBUG]  Perturb 36 => avg norm 10.00000
# [DEBUG]  Perturb 37 => avg norm 10.00000
# [DEBUG]  Perturb 38 => avg norm 10.00000
# [DEBUG]  Perturb 39 => avg norm 10.00000
# [DEBUG]  Perturb 40 => avg norm 10.00000
# [DEBUG]  Perturb 41 => avg norm 10.00000
# [DEBUG]  Perturb 42 => avg norm 10.00000
# [DEBUG]  Perturb 43 => avg norm 10.00000
# [DEBUG]  Perturb 44 => avg norm 10.00000
# [DEBUG]  Perturb 45 => avg norm 10.00000
# [DEBUG]  Perturb 46 => avg norm 10.00000
# [DEBUG]  Perturb 47 => avg norm 10.00000
# [DEBUG]  Perturb 48 => avg norm 10.00000
# [DEBUG]  Perturb 49 => avg norm 10.00000
# [DEBUG]  Perturb 50 => avg norm 10.00000
# [DEBUG]  Perturb 51 => avg norm 10.00000
# [DEBUG]  Perturb 52 => avg norm 10.00000
# [DEBUG]  Perturb 53 => avg norm 10.00000
# [DEBUG]  Perturb 54 => avg norm 10.00000
# [DEBUG]  Perturb 55 => avg norm 10.00000
# [DEBUG]  Perturb 56 => avg norm 10.00000
# [DEBUG]  Perturb 57 => avg norm 10.00000
# [DEBUG]  Perturb 58 => avg norm 10.00000
# [DEBUG]  Perturb 59 => avg norm 10.00000
# [DEBUG]  Perturb 60 => avg norm 10.00000
# [DEBUG]  Perturb 61 => avg norm 10.00000
# [DEBUG]  Perturb 62 => avg norm 10.00000
# [DEBUG]  Perturb 63 => avg norm 10.00000
# [DEBUG]  Perturb 64 => avg norm 10.00000
# [DEBUG]  Perturb 65 => avg norm 10.00000
# [DEBUG]  Perturb 66 => avg norm 10.00000
# [DEBUG]  Perturb 67 => avg norm 10.00000
# [DEBUG]  Perturb 68 => avg norm 10.00000
# [DEBUG]  Perturb 69 => avg norm 10.00000
# [DEBUG]  Perturb 70 => avg norm 10.00000
# [DEBUG]  Perturb 71 => avg norm 10.00000
# [DEBUG]  Perturb 72 => avg norm 10.00000
# [DEBUG]  Perturb 73 => avg norm 10.00000
# [DEBUG]  Perturb 74 => avg norm 10.00000
# [DEBUG]  Perturb 75 => avg norm 10.00000
# [DEBUG]  Perturb 76 => avg norm 10.00000
# [DEBUG]  Perturb 77 => avg norm 10.00000
# [DEBUG]  Perturb 78 => avg norm 10.00000
# [DEBUG]  Perturb 79 => avg norm 10.00000
# [DEBUG]  Perturb 80 => avg norm 10.00000
# [DEBUG]  Perturb 81 => avg norm 10.00000
# [DEBUG]  Perturb 82 => avg norm 10.00000
# [DEBUG]  Perturb 83 => avg norm 10.00000
# [DEBUG]  Perturb 84 => avg norm 10.00000
# [DEBUG]  Perturb 85 => avg norm 10.00000
# [DEBUG]  Perturb 86 => avg norm 10.00000
# [DEBUG]  Perturb 87 => avg norm 10.00000
# [DEBUG]  Perturb 88 => avg norm 10.00000
# [DEBUG]  Perturb 89 => avg norm 10.00000
# [DEBUG]  Perturb 90 => avg norm 10.00000
# [DEBUG]  Perturb 91 => avg norm 10.00000
# [DEBUG]  Perturb 92 => avg norm 10.00000
# [DEBUG]  Perturb 93 => avg norm 10.00000
# [DEBUG]  Perturb 94 => avg norm 10.00000
# [DEBUG]  Perturb 95 => avg norm 10.00000
# [DEBUG]  Perturb 96 => avg norm 10.00000
# [DEBUG]  Perturb 97 => avg norm 10.00000
# [DEBUG]  Perturb 98 => avg norm 10.00000
# [DEBUG]  Perturb 99 => avg norm 10.00000
# [DEBUG] WeiPer average noise norm => 10.00000
# [DEBUG] Detected single feature tensor in first batch
# [DEBUG]  Perturb 0 => avg norm 10.00000
# [DEBUG]  Perturb 1 => avg norm 10.00000
# [DEBUG]  Perturb 2 => avg norm 10.00000
# [DEBUG]  Perturb 3 => avg norm 10.00000
# [DEBUG]  Perturb 4 => avg norm 10.00000
# [DEBUG]  Perturb 5 => avg norm 10.00000
# [DEBUG]  Perturb 6 => avg norm 10.00000
# [DEBUG]  Perturb 7 => avg norm 10.00000
# [DEBUG]  Perturb 8 => avg norm 10.00000
# [DEBUG]  Perturb 9 => avg norm 10.00000
# [DEBUG]  Perturb 10 => avg norm 10.00000
# [DEBUG]  Perturb 11 => avg norm 10.00000
# [DEBUG]  Perturb 12 => avg norm 10.00000
# [DEBUG]  Perturb 13 => avg norm 10.00000
# [DEBUG]  Perturb 14 => avg norm 10.00000
# [DEBUG]  Perturb 15 => avg norm 10.00000
# [DEBUG]  Perturb 16 => avg norm 10.00000
# [DEBUG]  Perturb 17 => avg norm 10.00000
# [DEBUG]  Perturb 18 => avg norm 10.00000
# [DEBUG]  Perturb 19 => avg norm 10.00000
# [DEBUG]  Perturb 20 => avg norm 10.00000
# [DEBUG]  Perturb 21 => avg norm 10.00000
# [DEBUG]  Perturb 22 => avg norm 10.00000
# [DEBUG]  Perturb 23 => avg norm 10.00000
# [DEBUG]  Perturb 24 => avg norm 10.00000
# [DEBUG]  Perturb 25 => avg norm 10.00000
# [DEBUG]  Perturb 26 => avg norm 10.00000
# [DEBUG]  Perturb 27 => avg norm 10.00000
# [DEBUG]  Perturb 28 => avg norm 10.00000
# [DEBUG]  Perturb 29 => avg norm 10.00000
# [DEBUG]  Perturb 30 => avg norm 10.00000
# [DEBUG]  Perturb 31 => avg norm 10.00000
# [DEBUG]  Perturb 32 => avg norm 10.00000
# [DEBUG]  Perturb 33 => avg norm 10.00000
# [DEBUG]  Perturb 34 => avg norm 10.00000
# [DEBUG]  Perturb 35 => avg norm 10.00000
# [DEBUG]  Perturb 36 => avg norm 10.00000
# [DEBUG]  Perturb 37 => avg norm 10.00000
# [DEBUG]  Perturb 38 => avg norm 10.00000
# [DEBUG]  Perturb 39 => avg norm 10.00000
# [DEBUG]  Perturb 40 => avg norm 10.00000
# [DEBUG]  Perturb 41 => avg norm 10.00000
# [DEBUG]  Perturb 42 => avg norm 10.00000
# [DEBUG]  Perturb 43 => avg norm 10.00000
# [DEBUG]  Perturb 44 => avg norm 10.00000
# [DEBUG]  Perturb 45 => avg norm 10.00000
# [DEBUG]  Perturb 46 => avg norm 10.00000
# [DEBUG]  Perturb 47 => avg norm 10.00000
# [DEBUG]  Perturb 48 => avg norm 10.00000
# [DEBUG]  Perturb 49 => avg norm 10.00000
# [DEBUG]  Perturb 50 => avg norm 10.00000
# [DEBUG]  Perturb 51 => avg norm 10.00000
# [DEBUG]  Perturb 52 => avg norm 10.00000
# [DEBUG]  Perturb 53 => avg norm 10.00000
# [DEBUG]  Perturb 54 => avg norm 10.00000
# [DEBUG]  Perturb 55 => avg norm 10.00000
# [DEBUG]  Perturb 56 => avg norm 10.00000
# [DEBUG]  Perturb 57 => avg norm 10.00000
# [DEBUG]  Perturb 58 => avg norm 10.00000
# [DEBUG]  Perturb 59 => avg norm 10.00000
# [DEBUG]  Perturb 60 => avg norm 10.00000
# [DEBUG]  Perturb 61 => avg norm 10.00000
# [DEBUG]  Perturb 62 => avg norm 10.00000
# [DEBUG]  Perturb 63 => avg norm 10.00000
# [DEBUG]  Perturb 64 => avg norm 10.00000
# [DEBUG]  Perturb 65 => avg norm 10.00000
# [DEBUG]  Perturb 66 => avg norm 10.00000
# [DEBUG]  Perturb 67 => avg norm 10.00000
# [DEBUG]  Perturb 68 => avg norm 10.00000
# [DEBUG]  Perturb 69 => avg norm 10.00000
# [DEBUG]  Perturb 70 => avg norm 10.00000
# [DEBUG]  Perturb 71 => avg norm 10.00000
# [DEBUG]  Perturb 72 => avg norm 10.00000
# [DEBUG]  Perturb 73 => avg norm 10.00000
# [DEBUG]  Perturb 74 => avg norm 10.00000
# [DEBUG]  Perturb 75 => avg norm 10.00000
# [DEBUG]  Perturb 76 => avg norm 10.00000
# [DEBUG]  Perturb 77 => avg norm 10.00000
# [DEBUG]  Perturb 78 => avg norm 10.00000
# [DEBUG]  Perturb 79 => avg norm 10.00000
# [DEBUG]  Perturb 80 => avg norm 10.00000
# [DEBUG]  Perturb 81 => avg norm 10.00000
# [DEBUG]  Perturb 82 => avg norm 10.00000
# [DEBUG]  Perturb 83 => avg norm 10.00000
# [DEBUG]  Perturb 84 => avg norm 10.00000
# [DEBUG]  Perturb 85 => avg norm 10.00000
# [DEBUG]  Perturb 86 => avg norm 10.00000
# [DEBUG]  Perturb 87 => avg norm 10.00000
# [DEBUG]  Perturb 88 => avg norm 10.00000
# [DEBUG]  Perturb 89 => avg norm 10.00000
# [DEBUG]  Perturb 90 => avg norm 10.00000
# [DEBUG]  Perturb 91 => avg norm 10.00000
# [DEBUG]  Perturb 92 => avg norm 10.00000
# [DEBUG]  Perturb 93 => avg norm 10.00000
# [DEBUG]  Perturb 94 => avg norm 10.00000
# [DEBUG]  Perturb 95 => avg norm 10.00000
# [DEBUG]  Perturb 96 => avg norm 10.00000
# [DEBUG]  Perturb 97 => avg norm 10.00000
# [DEBUG]  Perturb 98 => avg norm 10.00000
# [DEBUG]  Perturb 99 => avg norm 10.00000
# [DEBUG] WeiPer average noise norm => 10.00000
# [DEBUG] Detected single feature tensor in first batch
# [DEBUG]  Perturb 0 => avg norm 10.00000
# [DEBUG]  Perturb 1 => avg norm 10.00000
# [DEBUG]  Perturb 2 => avg norm 10.00000
# [DEBUG]  Perturb 3 => avg norm 10.00000
# [DEBUG]  Perturb 4 => avg norm 10.00000
# [DEBUG]  Perturb 5 => avg norm 10.00000
# [DEBUG]  Perturb 6 => avg norm 10.00000
# [DEBUG]  Perturb 7 => avg norm 10.00000
# [DEBUG]  Perturb 8 => avg norm 10.00000
# [DEBUG]  Perturb 9 => avg norm 10.00000
# [DEBUG]  Perturb 10 => avg norm 10.00000
# [DEBUG]  Perturb 11 => avg norm 10.00000
# [DEBUG]  Perturb 12 => avg norm 10.00000
# [DEBUG]  Perturb 13 => avg norm 10.00000
# [DEBUG]  Perturb 14 => avg norm 10.00000
# [DEBUG]  Perturb 15 => avg norm 10.00000
# [DEBUG]  Perturb 16 => avg norm 10.00000
# [DEBUG]  Perturb 17 => avg norm 10.00000
# [DEBUG]  Perturb 18 => avg norm 10.00000
# [DEBUG]  Perturb 19 => avg norm 10.00000
# [DEBUG]  Perturb 20 => avg norm 10.00000
# [DEBUG]  Perturb 21 => avg norm 10.00000
# [DEBUG]  Perturb 22 => avg norm 10.00000
# [DEBUG]  Perturb 23 => avg norm 10.00000
# [DEBUG]  Perturb 24 => avg norm 10.00000
# [DEBUG]  Perturb 25 => avg norm 10.00000
# [DEBUG]  Perturb 26 => avg norm 10.00000
# [DEBUG]  Perturb 27 => avg norm 10.00000
# [DEBUG]  Perturb 28 => avg norm 10.00000
# [DEBUG]  Perturb 29 => avg norm 10.00000
# [DEBUG]  Perturb 30 => avg norm 10.00000
# [DEBUG]  Perturb 31 => avg norm 10.00000
# [DEBUG]  Perturb 32 => avg norm 10.00000
# [DEBUG]  Perturb 33 => avg norm 10.00000
# [DEBUG]  Perturb 34 => avg norm 10.00000
# [DEBUG]  Perturb 35 => avg norm 10.00000
# [DEBUG]  Perturb 36 => avg norm 10.00000
# [DEBUG]  Perturb 37 => avg norm 10.00000
# [DEBUG]  Perturb 38 => avg norm 10.00000
# [DEBUG]  Perturb 39 => avg norm 10.00000
# [DEBUG]  Perturb 40 => avg norm 10.00000
# [DEBUG]  Perturb 41 => avg norm 10.00000
# [DEBUG]  Perturb 42 => avg norm 10.00000
# [DEBUG]  Perturb 43 => avg norm 10.00000
# [DEBUG]  Perturb 44 => avg norm 10.00000
# [DEBUG]  Perturb 45 => avg norm 10.00000
# [DEBUG]  Perturb 46 => avg norm 10.00000
# [DEBUG]  Perturb 47 => avg norm 10.00000
# [DEBUG]  Perturb 48 => avg norm 10.00000
# [DEBUG]  Perturb 49 => avg norm 10.00000
# [DEBUG]  Perturb 50 => avg norm 10.00000
# [DEBUG]  Perturb 51 => avg norm 10.00000
# [DEBUG]  Perturb 52 => avg norm 10.00000
# [DEBUG]  Perturb 53 => avg norm 10.00000
# [DEBUG]  Perturb 54 => avg norm 10.00000
# [DEBUG]  Perturb 55 => avg norm 10.00000
# [DEBUG]  Perturb 56 => avg norm 10.00000
# [DEBUG]  Perturb 57 => avg norm 10.00000
# [DEBUG]  Perturb 58 => avg norm 10.00000
# [DEBUG]  Perturb 59 => avg norm 10.00000
# [DEBUG]  Perturb 60 => avg norm 10.00000
# [DEBUG]  Perturb 61 => avg norm 10.00000
# [DEBUG]  Perturb 62 => avg norm 10.00000
# [DEBUG]  Perturb 63 => avg norm 10.00000
# [DEBUG]  Perturb 64 => avg norm 10.00000
# [DEBUG]  Perturb 65 => avg norm 10.00000
# [DEBUG]  Perturb 66 => avg norm 10.00000
# [DEBUG]  Perturb 67 => avg norm 10.00000
# [DEBUG]  Perturb 68 => avg norm 10.00000
# [DEBUG]  Perturb 69 => avg norm 10.00000
# [DEBUG]  Perturb 70 => avg norm 10.00000
# [DEBUG]  Perturb 71 => avg norm 10.00000
# [DEBUG]  Perturb 72 => avg norm 10.00000
# [DEBUG]  Perturb 73 => avg norm 10.00000
# [DEBUG]  Perturb 74 => avg norm 10.00000
# [DEBUG]  Perturb 75 => avg norm 10.00000
# [DEBUG]  Perturb 76 => avg norm 10.00000
# [DEBUG]  Perturb 77 => avg norm 10.00000
# [DEBUG]  Perturb 78 => avg norm 10.00000
# [DEBUG]  Perturb 79 => avg norm 10.00000
# [DEBUG]  Perturb 80 => avg norm 10.00000
# [DEBUG]  Perturb 81 => avg norm 10.00000
# [DEBUG]  Perturb 82 => avg norm 10.00000
# [DEBUG]  Perturb 83 => avg norm 10.00000
# [DEBUG]  Perturb 84 => avg norm 10.00000
# [DEBUG]  Perturb 85 => avg norm 10.00000
# [DEBUG]  Perturb 86 => avg norm 10.00000
# [DEBUG]  Perturb 87 => avg norm 10.00000
# [DEBUG]  Perturb 88 => avg norm 10.00000
# [DEBUG]  Perturb 89 => avg norm 10.00000
# [DEBUG]  Perturb 90 => avg norm 10.00000
# [DEBUG]  Perturb 91 => avg norm 10.00000
# [DEBUG]  Perturb 92 => avg norm 10.00000
# [DEBUG]  Perturb 93 => avg norm 10.00000
# [DEBUG]  Perturb 94 => avg norm 10.00000
# [DEBUG]  Perturb 95 => avg norm 10.00000
# [DEBUG]  Perturb 96 => avg norm 10.00000
# [DEBUG]  Perturb 97 => avg norm 10.00000
# [DEBUG]  Perturb 98 => avg norm 10.00000
# [DEBUG]  Perturb 99 => avg norm 10.00000
# [DEBUG] WeiPer average noise norm => 10.00000
# [DEBUG] single-layer => pen-latent scanning => ((0.0, 3.865647792816162), (-18.07172393798828, 25.08176612854004))
# [DEBUG] Detected single feature tensor in first batch
# [DEBUG]  Perturb 0 => avg norm 19.70401
# [DEBUG]  Perturb 1 => avg norm 19.70401
# [DEBUG]  Perturb 2 => avg norm 19.70401
# [DEBUG]  Perturb 3 => avg norm 19.70401
# [DEBUG]  Perturb 4 => avg norm 19.70401
# [DEBUG]  Perturb 5 => avg norm 19.70401
# [DEBUG]  Perturb 6 => avg norm 19.70401
# [DEBUG]  Perturb 7 => avg norm 19.70401
# [DEBUG]  Perturb 8 => avg norm 19.70401
# [DEBUG]  Perturb 9 => avg norm 19.70401
# [DEBUG]  Perturb 10 => avg norm 19.70401
# [DEBUG]  Perturb 11 => avg norm 19.70401
# [DEBUG]  Perturb 12 => avg norm 19.70401
# [DEBUG]  Perturb 13 => avg norm 19.70401
# [DEBUG]  Perturb 14 => avg norm 19.70401
# [DEBUG]  Perturb 15 => avg norm 19.70401
# [DEBUG]  Perturb 16 => avg norm 19.70401
# [DEBUG]  Perturb 17 => avg norm 19.70401
# [DEBUG]  Perturb 18 => avg norm 19.70401
# [DEBUG]  Perturb 19 => avg norm 19.70401
# [DEBUG]  Perturb 20 => avg norm 19.70401
# [DEBUG]  Perturb 21 => avg norm 19.70401
# [DEBUG]  Perturb 22 => avg norm 19.70401
# [DEBUG]  Perturb 23 => avg norm 19.70401
# [DEBUG]  Perturb 24 => avg norm 19.70401
# [DEBUG]  Perturb 25 => avg norm 19.70401
# [DEBUG]  Perturb 26 => avg norm 19.70401
# [DEBUG]  Perturb 27 => avg norm 19.70401
# [DEBUG]  Perturb 28 => avg norm 19.70401
# [DEBUG]  Perturb 29 => avg norm 19.70401
# [DEBUG]  Perturb 30 => avg norm 19.70401
# [DEBUG]  Perturb 31 => avg norm 19.70401
# [DEBUG]  Perturb 32 => avg norm 19.70401
# [DEBUG]  Perturb 33 => avg norm 19.70401
# [DEBUG]  Perturb 34 => avg norm 19.70401
# [DEBUG]  Perturb 35 => avg norm 19.70401
# [DEBUG]  Perturb 36 => avg norm 19.70401
# [DEBUG]  Perturb 37 => avg norm 19.70401
# [DEBUG]  Perturb 38 => avg norm 19.70401
# [DEBUG]  Perturb 39 => avg norm 19.70401
# [DEBUG]  Perturb 40 => avg norm 19.70401
# [DEBUG]  Perturb 41 => avg norm 19.70401
# [DEBUG]  Perturb 42 => avg norm 19.70401
# [DEBUG]  Perturb 43 => avg norm 19.70401
# [DEBUG]  Perturb 44 => avg norm 19.70401
# [DEBUG]  Perturb 45 => avg norm 19.70401
# [DEBUG]  Perturb 46 => avg norm 19.70401
# [DEBUG]  Perturb 47 => avg norm 19.70401
# [DEBUG]  Perturb 48 => avg norm 19.70401
# [DEBUG]  Perturb 49 => avg norm 19.70401
# [DEBUG]  Perturb 50 => avg norm 19.70401
# [DEBUG]  Perturb 51 => avg norm 19.70401
# [DEBUG]  Perturb 52 => avg norm 19.70401
# [DEBUG]  Perturb 53 => avg norm 19.70401
# [DEBUG]  Perturb 54 => avg norm 19.70401
# [DEBUG]  Perturb 55 => avg norm 19.70401
# [DEBUG]  Perturb 56 => avg norm 19.70401
# [DEBUG]  Perturb 57 => avg norm 19.70401
# [DEBUG]  Perturb 58 => avg norm 19.70401
# [DEBUG]  Perturb 59 => avg norm 19.70401
# [DEBUG]  Perturb 60 => avg norm 19.70401
# [DEBUG]  Perturb 61 => avg norm 19.70401
# [DEBUG]  Perturb 62 => avg norm 19.70401
# [DEBUG]  Perturb 63 => avg norm 19.70401
# [DEBUG]  Perturb 64 => avg norm 19.70401
# [DEBUG]  Perturb 65 => avg norm 19.70401
# [DEBUG]  Perturb 66 => avg norm 19.70401
# [DEBUG]  Perturb 67 => avg norm 19.70401
# [DEBUG]  Perturb 68 => avg norm 19.70401
# [DEBUG]  Perturb 69 => avg norm 19.70401
# [DEBUG]  Perturb 70 => avg norm 19.70401
# [DEBUG]  Perturb 71 => avg norm 19.70401
# [DEBUG]  Perturb 72 => avg norm 19.70401
# [DEBUG]  Perturb 73 => avg norm 19.70401
# [DEBUG]  Perturb 74 => avg norm 19.70401
# [DEBUG]  Perturb 75 => avg norm 19.70401
# [DEBUG]  Perturb 76 => avg norm 19.70401
# [DEBUG]  Perturb 77 => avg norm 19.70401
# [DEBUG]  Perturb 78 => avg norm 19.70401
# [DEBUG]  Perturb 79 => avg norm 19.70401
# [DEBUG]  Perturb 80 => avg norm 19.70401
# [DEBUG]  Perturb 81 => avg norm 19.70401
# [DEBUG]  Perturb 82 => avg norm 19.70401
# [DEBUG]  Perturb 83 => avg norm 19.70401
# [DEBUG]  Perturb 84 => avg norm 19.70401
# [DEBUG]  Perturb 85 => avg norm 19.70401
# [DEBUG]  Perturb 86 => avg norm 19.70401
# [DEBUG]  Perturb 87 => avg norm 19.70401
# [DEBUG]  Perturb 88 => avg norm 19.70401
# [DEBUG]  Perturb 89 => avg norm 19.70401
# [DEBUG]  Perturb 90 => avg norm 19.70401
# [DEBUG]  Perturb 91 => avg norm 19.70401
# [DEBUG]  Perturb 92 => avg norm 19.70401
# [DEBUG]  Perturb 93 => avg norm 19.70401
# [DEBUG]  Perturb 94 => avg norm 19.70401
# [DEBUG]  Perturb 95 => avg norm 19.70401
# [DEBUG]  Perturb 96 => avg norm 19.70401
# [DEBUG]  Perturb 97 => avg norm 19.70401
# [DEBUG]  Perturb 98 => avg norm 19.70401
# [DEBUG]  Perturb 99 => avg norm 19.70401
# [DEBUG] WeiPer average noise norm => 19.70401
# [DEBUG] Detected single feature tensor in first batch
# [DEBUG]  Perturb 0 => avg norm 19.70401
# [DEBUG]  Perturb 1 => avg norm 19.70401
# [DEBUG]  Perturb 2 => avg norm 19.70401
# [DEBUG]  Perturb 3 => avg norm 19.70401
# [DEBUG]  Perturb 4 => avg norm 19.70401
# [DEBUG]  Perturb 5 => avg norm 19.70401
# [DEBUG]  Perturb 6 => avg norm 19.70401
# [DEBUG]  Perturb 7 => avg norm 19.70401
# [DEBUG]  Perturb 8 => avg norm 19.70401
# [DEBUG]  Perturb 9 => avg norm 19.70401
# [DEBUG]  Perturb 10 => avg norm 19.70401
# [DEBUG]  Perturb 11 => avg norm 19.70401
# [DEBUG]  Perturb 12 => avg norm 19.70401
# [DEBUG]  Perturb 13 => avg norm 19.70401
# [DEBUG]  Perturb 14 => avg norm 19.70401
# [DEBUG]  Perturb 15 => avg norm 19.70401
# [DEBUG]  Perturb 16 => avg norm 19.70401
# [DEBUG]  Perturb 17 => avg norm 19.70401
# [DEBUG]  Perturb 18 => avg norm 19.70401
# [DEBUG]  Perturb 19 => avg norm 19.70401
# [DEBUG]  Perturb 20 => avg norm 19.70401
# [DEBUG]  Perturb 21 => avg norm 19.70401
# [DEBUG]  Perturb 22 => avg norm 19.70401
# [DEBUG]  Perturb 23 => avg norm 19.70401
# [DEBUG]  Perturb 24 => avg norm 19.70401
# [DEBUG]  Perturb 25 => avg norm 19.70401
# [DEBUG]  Perturb 26 => avg norm 19.70401
# [DEBUG]  Perturb 27 => avg norm 19.70401
# [DEBUG]  Perturb 28 => avg norm 19.70401
# [DEBUG]  Perturb 29 => avg norm 19.70401
# [DEBUG]  Perturb 30 => avg norm 19.70401
# [DEBUG]  Perturb 31 => avg norm 19.70401
# [DEBUG]  Perturb 32 => avg norm 19.70401
# [DEBUG]  Perturb 33 => avg norm 19.70401
# [DEBUG]  Perturb 34 => avg norm 19.70401
# [DEBUG]  Perturb 35 => avg norm 19.70401
# [DEBUG]  Perturb 36 => avg norm 19.70401
# [DEBUG]  Perturb 37 => avg norm 19.70401
# [DEBUG]  Perturb 38 => avg norm 19.70401
# [DEBUG]  Perturb 39 => avg norm 19.70401
# [DEBUG]  Perturb 40 => avg norm 19.70401
# [DEBUG]  Perturb 41 => avg norm 19.70401
# [DEBUG]  Perturb 42 => avg norm 19.70401
# [DEBUG]  Perturb 43 => avg norm 19.70401
# [DEBUG]  Perturb 44 => avg norm 19.70401
# [DEBUG]  Perturb 45 => avg norm 19.70401
# [DEBUG]  Perturb 46 => avg norm 19.70401
# [DEBUG]  Perturb 47 => avg norm 19.70401
# [DEBUG]  Perturb 48 => avg norm 19.70401
# [DEBUG]  Perturb 49 => avg norm 19.70401
# [DEBUG]  Perturb 50 => avg norm 19.70401
# [DEBUG]  Perturb 51 => avg norm 19.70401
# [DEBUG]  Perturb 52 => avg norm 19.70401
# [DEBUG]  Perturb 53 => avg norm 19.70401
# [DEBUG]  Perturb 54 => avg norm 19.70401
# [DEBUG]  Perturb 55 => avg norm 19.70401
# [DEBUG]  Perturb 56 => avg norm 19.70401
# [DEBUG]  Perturb 57 => avg norm 19.70401
# [DEBUG]  Perturb 58 => avg norm 19.70401
# [DEBUG]  Perturb 59 => avg norm 19.70401
# [DEBUG]  Perturb 60 => avg norm 19.70401
# [DEBUG]  Perturb 61 => avg norm 19.70401
# [DEBUG]  Perturb 62 => avg norm 19.70401
# [DEBUG]  Perturb 63 => avg norm 19.70401
# [DEBUG]  Perturb 64 => avg norm 19.70401
# [DEBUG]  Perturb 65 => avg norm 19.70401
# [DEBUG]  Perturb 66 => avg norm 19.70401
# [DEBUG]  Perturb 67 => avg norm 19.70401
# [DEBUG]  Perturb 68 => avg norm 19.70401
# [DEBUG]  Perturb 69 => avg norm 19.70401
# [DEBUG]  Perturb 70 => avg norm 19.70401
# [DEBUG]  Perturb 71 => avg norm 19.70401
# [DEBUG]  Perturb 72 => avg norm 19.70401
# [DEBUG]  Perturb 73 => avg norm 19.70401
# [DEBUG]  Perturb 74 => avg norm 19.70401
# [DEBUG]  Perturb 75 => avg norm 19.70401
# [DEBUG]  Perturb 76 => avg norm 19.70401
# [DEBUG]  Perturb 77 => avg norm 19.70401
# [DEBUG]  Perturb 78 => avg norm 19.70401
# [DEBUG]  Perturb 79 => avg norm 19.70401
# [DEBUG]  Perturb 80 => avg norm 19.70401
# [DEBUG]  Perturb 81 => avg norm 19.70401
# [DEBUG]  Perturb 82 => avg norm 19.70401
# [DEBUG]  Perturb 83 => avg norm 19.70401
# [DEBUG]  Perturb 84 => avg norm 19.70401
# [DEBUG]  Perturb 85 => avg norm 19.70401
# [DEBUG]  Perturb 86 => avg norm 19.70401
# [DEBUG]  Perturb 87 => avg norm 19.70401
# [DEBUG]  Perturb 88 => avg norm 19.70401
# [DEBUG]  Perturb 89 => avg norm 19.70401
# [DEBUG]  Perturb 90 => avg norm 19.70401
# [DEBUG]  Perturb 91 => avg norm 19.70401
# [DEBUG]  Perturb 92 => avg norm 19.70401
# [DEBUG]  Perturb 93 => avg norm 19.70401
# [DEBUG]  Perturb 94 => avg norm 19.70401
# [DEBUG]  Perturb 95 => avg norm 19.70401
# [DEBUG]  Perturb 96 => avg norm 19.70401
# [DEBUG]  Perturb 97 => avg norm 19.70401
# [DEBUG]  Perturb 98 => avg norm 19.70401
# [DEBUG]  Perturb 99 => avg norm 19.70401
# [DEBUG] WeiPer average noise norm => 19.70401
# [DEBUG] Detected single feature tensor in first batch
# [DEBUG]  Perturb 0 => avg norm 19.70401
# [DEBUG]  Perturb 1 => avg norm 19.70401
# [DEBUG]  Perturb 2 => avg norm 19.70401
# [DEBUG]  Perturb 3 => avg norm 19.70401
# [DEBUG]  Perturb 4 => avg norm 19.70401
# [DEBUG]  Perturb 5 => avg norm 19.70401
# [DEBUG]  Perturb 6 => avg norm 19.70401
# [DEBUG]  Perturb 7 => avg norm 19.70401
# [DEBUG]  Perturb 8 => avg norm 19.70401
# [DEBUG]  Perturb 9 => avg norm 19.70401
# [DEBUG]  Perturb 10 => avg norm 19.70401
# [DEBUG]  Perturb 11 => avg norm 19.70401
# [DEBUG]  Perturb 12 => avg norm 19.70401
# [DEBUG]  Perturb 13 => avg norm 19.70401
# [DEBUG]  Perturb 14 => avg norm 19.70401
# [DEBUG]  Perturb 15 => avg norm 19.70401
# [DEBUG]  Perturb 16 => avg norm 19.70401
# [DEBUG]  Perturb 17 => avg norm 19.70401
# [DEBUG]  Perturb 18 => avg norm 19.70401
# [DEBUG]  Perturb 19 => avg norm 19.70401
# [DEBUG]  Perturb 20 => avg norm 19.70401
# [DEBUG]  Perturb 21 => avg norm 19.70401
# [DEBUG]  Perturb 22 => avg norm 19.70401
# [DEBUG]  Perturb 23 => avg norm 19.70401
# [DEBUG]  Perturb 24 => avg norm 19.70401
# [DEBUG]  Perturb 25 => avg norm 19.70401
# [DEBUG]  Perturb 26 => avg norm 19.70401
# [DEBUG]  Perturb 27 => avg norm 19.70401
# [DEBUG]  Perturb 28 => avg norm 19.70401
# [DEBUG]  Perturb 29 => avg norm 19.70401
# [DEBUG]  Perturb 30 => avg norm 19.70401
# [DEBUG]  Perturb 31 => avg norm 19.70401
# [DEBUG]  Perturb 32 => avg norm 19.70401
# [DEBUG]  Perturb 33 => avg norm 19.70401
# [DEBUG]  Perturb 34 => avg norm 19.70401
# [DEBUG]  Perturb 35 => avg norm 19.70401
# [DEBUG]  Perturb 36 => avg norm 19.70401
# [DEBUG]  Perturb 37 => avg norm 19.70401
# [DEBUG]  Perturb 38 => avg norm 19.70401
# [DEBUG]  Perturb 39 => avg norm 19.70401
# [DEBUG]  Perturb 40 => avg norm 19.70401
# [DEBUG]  Perturb 41 => avg norm 19.70401
# [DEBUG]  Perturb 42 => avg norm 19.70401
# [DEBUG]  Perturb 43 => avg norm 19.70401
# [DEBUG]  Perturb 44 => avg norm 19.70401
# [DEBUG]  Perturb 45 => avg norm 19.70401
# [DEBUG]  Perturb 46 => avg norm 19.70401
# [DEBUG]  Perturb 47 => avg norm 19.70401
# [DEBUG]  Perturb 48 => avg norm 19.70401
# [DEBUG]  Perturb 49 => avg norm 19.70401
# [DEBUG]  Perturb 50 => avg norm 19.70401
# [DEBUG]  Perturb 51 => avg norm 19.70401
# [DEBUG]  Perturb 52 => avg norm 19.70401
# [DEBUG]  Perturb 53 => avg norm 19.70401
# [DEBUG]  Perturb 54 => avg norm 19.70401
# [DEBUG]  Perturb 55 => avg norm 19.70401
# [DEBUG]  Perturb 56 => avg norm 19.70401
# [DEBUG]  Perturb 57 => avg norm 19.70401
# [DEBUG]  Perturb 58 => avg norm 19.70401
# [DEBUG]  Perturb 59 => avg norm 19.70401
# [DEBUG]  Perturb 60 => avg norm 19.70401
# [DEBUG]  Perturb 61 => avg norm 19.70401
# [DEBUG]  Perturb 62 => avg norm 19.70401
# [DEBUG]  Perturb 63 => avg norm 19.70401
# [DEBUG]  Perturb 64 => avg norm 19.70401
# [DEBUG]  Perturb 65 => avg norm 19.70401
# [DEBUG]  Perturb 66 => avg norm 19.70401
# [DEBUG]  Perturb 67 => avg norm 19.70401
# [DEBUG]  Perturb 68 => avg norm 19.70401
# [DEBUG]  Perturb 69 => avg norm 19.70401
# [DEBUG]  Perturb 70 => avg norm 19.70401
# [DEBUG]  Perturb 71 => avg norm 19.70401
# [DEBUG]  Perturb 72 => avg norm 19.70401
# [DEBUG]  Perturb 73 => avg norm 19.70401
# [DEBUG]  Perturb 74 => avg norm 19.70401
# [DEBUG]  Perturb 75 => avg norm 19.70401
# [DEBUG]  Perturb 76 => avg norm 19.70401
# [DEBUG]  Perturb 77 => avg norm 19.70401
# [DEBUG]  Perturb 78 => avg norm 19.70401
# [DEBUG]  Perturb 79 => avg norm 19.70401
# [DEBUG]  Perturb 80 => avg norm 19.70401
# [DEBUG]  Perturb 81 => avg norm 19.70401
# [DEBUG]  Perturb 82 => avg norm 19.70401
# [DEBUG]  Perturb 83 => avg norm 19.70401
# [DEBUG]  Perturb 84 => avg norm 19.70401
# [DEBUG]  Perturb 85 => avg norm 19.70401
# [DEBUG]  Perturb 86 => avg norm 19.70401
# [DEBUG]  Perturb 87 => avg norm 19.70401
# [DEBUG]  Perturb 88 => avg norm 19.70401
# [DEBUG]  Perturb 89 => avg norm 19.70401
# [DEBUG]  Perturb 90 => avg norm 19.70401
# [DEBUG]  Perturb 91 => avg norm 19.70401
# [DEBUG]  Perturb 92 => avg norm 19.70401
# [DEBUG]  Perturb 93 => avg norm 19.70401
# [DEBUG]  Perturb 94 => avg norm 19.70401
# [DEBUG]  Perturb 95 => avg norm 19.70401
# [DEBUG]  Perturb 96 => avg norm 19.70401
# [DEBUG]  Perturb 97 => avg norm 19.70401
# [DEBUG]  Perturb 98 => avg norm 19.70401
# [DEBUG]  Perturb 99 => avg norm 19.70401
# [DEBUG] WeiPer average noise norm => 19.70401
# [DEBUG] Detected single feature tensor in first batch
# [DEBUG]  Perturb 0 => avg norm 19.70401
# [DEBUG]  Perturb 1 => avg norm 19.70401
# [DEBUG]  Perturb 2 => avg norm 19.70401
# [DEBUG]  Perturb 3 => avg norm 19.70401
# [DEBUG]  Perturb 4 => avg norm 19.70401
# [DEBUG]  Perturb 5 => avg norm 19.70401
# [DEBUG]  Perturb 6 => avg norm 19.70401
# [DEBUG]  Perturb 7 => avg norm 19.70401
# [DEBUG]  Perturb 8 => avg norm 19.70401
# [DEBUG]  Perturb 9 => avg norm 19.70401
# [DEBUG]  Perturb 10 => avg norm 19.70401
# [DEBUG]  Perturb 11 => avg norm 19.70401
# [DEBUG]  Perturb 12 => avg norm 19.70401
# [DEBUG]  Perturb 13 => avg norm 19.70401
# [DEBUG]  Perturb 14 => avg norm 19.70401
# [DEBUG]  Perturb 15 => avg norm 19.70401
# [DEBUG]  Perturb 16 => avg norm 19.70401
# [DEBUG]  Perturb 17 => avg norm 19.70401
# [DEBUG]  Perturb 18 => avg norm 19.70401
# [DEBUG]  Perturb 19 => avg norm 19.70401
# [DEBUG]  Perturb 20 => avg norm 19.70401
# [DEBUG]  Perturb 21 => avg norm 19.70401
# [DEBUG]  Perturb 22 => avg norm 19.70401
# [DEBUG]  Perturb 23 => avg norm 19.70401
# [DEBUG]  Perturb 24 => avg norm 19.70401
# [DEBUG]  Perturb 25 => avg norm 19.70401
# [DEBUG]  Perturb 26 => avg norm 19.70401
# [DEBUG]  Perturb 27 => avg norm 19.70401
# [DEBUG]  Perturb 28 => avg norm 19.70401
# [DEBUG]  Perturb 29 => avg norm 19.70401
# [DEBUG]  Perturb 30 => avg norm 19.70401
# [DEBUG]  Perturb 31 => avg norm 19.70401
# [DEBUG]  Perturb 32 => avg norm 19.70401
# [DEBUG]  Perturb 33 => avg norm 19.70401
# [DEBUG]  Perturb 34 => avg norm 19.70401
# [DEBUG]  Perturb 35 => avg norm 19.70401
# [DEBUG]  Perturb 36 => avg norm 19.70401
# [DEBUG]  Perturb 37 => avg norm 19.70401
# [DEBUG]  Perturb 38 => avg norm 19.70401
# [DEBUG]  Perturb 39 => avg norm 19.70401
# [DEBUG]  Perturb 40 => avg norm 19.70401
# [DEBUG]  Perturb 41 => avg norm 19.70401
# [DEBUG]  Perturb 42 => avg norm 19.70401
# [DEBUG]  Perturb 43 => avg norm 19.70401
# [DEBUG]  Perturb 44 => avg norm 19.70401
# [DEBUG]  Perturb 45 => avg norm 19.70401
# [DEBUG]  Perturb 46 => avg norm 19.70401
# [DEBUG]  Perturb 47 => avg norm 19.70401
# [DEBUG]  Perturb 48 => avg norm 19.70401
# [DEBUG]  Perturb 49 => avg norm 19.70401
# [DEBUG]  Perturb 50 => avg norm 19.70401
# [DEBUG]  Perturb 51 => avg norm 19.70401
# [DEBUG]  Perturb 52 => avg norm 19.70401
# [DEBUG]  Perturb 53 => avg norm 19.70401
# [DEBUG]  Perturb 54 => avg norm 19.70401
# [DEBUG]  Perturb 55 => avg norm 19.70401
# [DEBUG]  Perturb 56 => avg norm 19.70401
# [DEBUG]  Perturb 57 => avg norm 19.70401
# [DEBUG]  Perturb 58 => avg norm 19.70401
# [DEBUG]  Perturb 59 => avg norm 19.70401
# [DEBUG]  Perturb 60 => avg norm 19.70401
# [DEBUG]  Perturb 61 => avg norm 19.70401
# [DEBUG]  Perturb 62 => avg norm 19.70401
# [DEBUG]  Perturb 63 => avg norm 19.70401
# [DEBUG]  Perturb 64 => avg norm 19.70401
# [DEBUG]  Perturb 65 => avg norm 19.70401
# [DEBUG]  Perturb 66 => avg norm 19.70401
# [DEBUG]  Perturb 67 => avg norm 19.70401
# [DEBUG]  Perturb 68 => avg norm 19.70401
# [DEBUG]  Perturb 69 => avg norm 19.70401
# [DEBUG]  Perturb 70 => avg norm 19.70401
# [DEBUG]  Perturb 71 => avg norm 19.70401
# [DEBUG]  Perturb 72 => avg norm 19.70401
# [DEBUG]  Perturb 73 => avg norm 19.70401
# [DEBUG]  Perturb 74 => avg norm 19.70401
# [DEBUG]  Perturb 75 => avg norm 19.70401
# [DEBUG]  Perturb 76 => avg norm 19.70401
# [DEBUG]  Perturb 77 => avg norm 19.70401
# [DEBUG]  Perturb 78 => avg norm 19.70401
# [DEBUG]  Perturb 79 => avg norm 19.70401
# [DEBUG]  Perturb 80 => avg norm 19.70401
# [DEBUG]  Perturb 81 => avg norm 19.70401
# [DEBUG]  Perturb 82 => avg norm 19.70401
# [DEBUG]  Perturb 83 => avg norm 19.70401
# [DEBUG]  Perturb 84 => avg norm 19.70401
# [DEBUG]  Perturb 85 => avg norm 19.70401
# [DEBUG]  Perturb 86 => avg norm 19.70401
# [DEBUG]  Perturb 87 => avg norm 19.70401
# [DEBUG]  Perturb 88 => avg norm 19.70401
# [DEBUG]  Perturb 89 => avg norm 19.70401
# [DEBUG]  Perturb 90 => avg norm 19.70401
# [DEBUG]  Perturb 91 => avg norm 19.70401
# [DEBUG]  Perturb 92 => avg norm 19.70401
# [DEBUG]  Perturb 93 => avg norm 19.70401
# [DEBUG]  Perturb 94 => avg norm 19.70401
# [DEBUG]  Perturb 95 => avg norm 19.70401
# [DEBUG]  Perturb 96 => avg norm 19.70401
# [DEBUG]  Perturb 97 => avg norm 19.70401
# [DEBUG]  Perturb 98 => avg norm 19.70401
# [DEBUG]  Perturb 99 => avg norm 19.70401
# [DEBUG] WeiPer average noise norm => 19.70401
# [DEBUG] Detected single feature tensor in first batch
# [DEBUG]  Perturb 0 => avg norm 19.70401
# [DEBUG]  Perturb 1 => avg norm 19.70401
# [DEBUG]  Perturb 2 => avg norm 19.70401
# [DEBUG]  Perturb 3 => avg norm 19.70401
# [DEBUG]  Perturb 4 => avg norm 19.70401
# [DEBUG]  Perturb 5 => avg norm 19.70401
# [DEBUG]  Perturb 6 => avg norm 19.70401
# [DEBUG]  Perturb 7 => avg norm 19.70401
# [DEBUG]  Perturb 8 => avg norm 19.70401
# [DEBUG]  Perturb 9 => avg norm 19.70401
# [DEBUG]  Perturb 10 => avg norm 19.70401
# [DEBUG]  Perturb 11 => avg norm 19.70401
# [DEBUG]  Perturb 12 => avg norm 19.70401
# [DEBUG]  Perturb 13 => avg norm 19.70401
# [DEBUG]  Perturb 14 => avg norm 19.70401
# [DEBUG]  Perturb 15 => avg norm 19.70401
# [DEBUG]  Perturb 16 => avg norm 19.70401
# [DEBUG]  Perturb 17 => avg norm 19.70401
# [DEBUG]  Perturb 18 => avg norm 19.70401
# [DEBUG]  Perturb 19 => avg norm 19.70401
# [DEBUG]  Perturb 20 => avg norm 19.70401
# [DEBUG]  Perturb 21 => avg norm 19.70401
# [DEBUG]  Perturb 22 => avg norm 19.70401
# [DEBUG]  Perturb 23 => avg norm 19.70401
# [DEBUG]  Perturb 24 => avg norm 19.70401
# [DEBUG]  Perturb 25 => avg norm 19.70401
# [DEBUG]  Perturb 26 => avg norm 19.70401
# [DEBUG]  Perturb 27 => avg norm 19.70401
# [DEBUG]  Perturb 28 => avg norm 19.70401
# [DEBUG]  Perturb 29 => avg norm 19.70401
# [DEBUG]  Perturb 30 => avg norm 19.70401
# [DEBUG]  Perturb 31 => avg norm 19.70401
# [DEBUG]  Perturb 32 => avg norm 19.70401
# [DEBUG]  Perturb 33 => avg norm 19.70401
# [DEBUG]  Perturb 34 => avg norm 19.70401
# [DEBUG]  Perturb 35 => avg norm 19.70401
# [DEBUG]  Perturb 36 => avg norm 19.70401
# [DEBUG]  Perturb 37 => avg norm 19.70401
# [DEBUG]  Perturb 38 => avg norm 19.70401
# [DEBUG]  Perturb 39 => avg norm 19.70401
# [DEBUG]  Perturb 40 => avg norm 19.70401
# [DEBUG]  Perturb 41 => avg norm 19.70401
# [DEBUG]  Perturb 42 => avg norm 19.70401
# [DEBUG]  Perturb 43 => avg norm 19.70401
# [DEBUG]  Perturb 44 => avg norm 19.70401
# [DEBUG]  Perturb 45 => avg norm 19.70401
# [DEBUG]  Perturb 46 => avg norm 19.70401
# [DEBUG]  Perturb 47 => avg norm 19.70401
# [DEBUG]  Perturb 48 => avg norm 19.70401
# [DEBUG]  Perturb 49 => avg norm 19.70401
# [DEBUG]  Perturb 50 => avg norm 19.70401
# [DEBUG]  Perturb 51 => avg norm 19.70401
# [DEBUG]  Perturb 52 => avg norm 19.70401
# [DEBUG]  Perturb 53 => avg norm 19.70401
# [DEBUG]  Perturb 54 => avg norm 19.70401
# [DEBUG]  Perturb 55 => avg norm 19.70401
# [DEBUG]  Perturb 56 => avg norm 19.70401
# [DEBUG]  Perturb 57 => avg norm 19.70401
# [DEBUG]  Perturb 58 => avg norm 19.70401
# [DEBUG]  Perturb 59 => avg norm 19.70401
# [DEBUG]  Perturb 60 => avg norm 19.70401
# [DEBUG]  Perturb 61 => avg norm 19.70401
# [DEBUG]  Perturb 62 => avg norm 19.70401
# [DEBUG]  Perturb 63 => avg norm 19.70401
# [DEBUG]  Perturb 64 => avg norm 19.70401
# [DEBUG]  Perturb 65 => avg norm 19.70401
# [DEBUG]  Perturb 66 => avg norm 19.70401
# [DEBUG]  Perturb 67 => avg norm 19.70401
# [DEBUG]  Perturb 68 => avg norm 19.70401
# [DEBUG]  Perturb 69 => avg norm 19.70401
# [DEBUG]  Perturb 70 => avg norm 19.70401
# [DEBUG]  Perturb 71 => avg norm 19.70401
# [DEBUG]  Perturb 72 => avg norm 19.70401
# [DEBUG]  Perturb 73 => avg norm 19.70401
# [DEBUG]  Perturb 74 => avg norm 19.70401
# [DEBUG]  Perturb 75 => avg norm 19.70401
# [DEBUG]  Perturb 76 => avg norm 19.70401
# [DEBUG]  Perturb 77 => avg norm 19.70401
# [DEBUG]  Perturb 78 => avg norm 19.70401
# [DEBUG]  Perturb 79 => avg norm 19.70401
# [DEBUG]  Perturb 80 => avg norm 19.70401
# [DEBUG]  Perturb 81 => avg norm 19.70401
# [DEBUG]  Perturb 82 => avg norm 19.70401
# [DEBUG]  Perturb 83 => avg norm 19.70401
# [DEBUG]  Perturb 84 => avg norm 19.70401
# [DEBUG]  Perturb 85 => avg norm 19.70401
# [DEBUG]  Perturb 86 => avg norm 19.70401
# [DEBUG]  Perturb 87 => avg norm 19.70401
# [DEBUG]  Perturb 88 => avg norm 19.70401
# [DEBUG]  Perturb 89 => avg norm 19.70401
# [DEBUG]  Perturb 90 => avg norm 19.70401
# [DEBUG]  Perturb 91 => avg norm 19.70401
# [DEBUG]  Perturb 92 => avg norm 19.70401
# [DEBUG]  Perturb 93 => avg norm 19.70401
# [DEBUG]  Perturb 94 => avg norm 19.70401
# [DEBUG]  Perturb 95 => avg norm 19.70401
# [DEBUG]  Perturb 96 => avg norm 19.70401
# [DEBUG]  Perturb 97 => avg norm 19.70401
# [DEBUG]  Perturb 98 => avg norm 19.70401
# [DEBUG]  Perturb 99 => avg norm 19.70401
# [DEBUG] WeiPer average noise norm => 19.70401
# [DEBUG] single-layer penultimate => final shape => torch.Size([100, 1]) torch.Size([100, 1])
# Performing inference on cifar10 test set...
#   0%|          | 0/1 [00:00<?, ?it/s]
# [DEBUG] Entering WeiPerKLDivPostprocessor.postprocess => aggregator_mode=none
# [DEBUG] single-layer penultimate postprocess => aggregator_mode='none' & single-layer
# [DEBUG] Detected single feature tensor in first batch
# [DEBUG]  Perturb 0 => avg norm 19.70401
# [DEBUG]  Perturb 1 => avg norm 19.70401
# [DEBUG]  Perturb 2 => avg norm 19.70401
# [DEBUG]  Perturb 3 => avg norm 19.70401
# [DEBUG]  Perturb 4 => avg norm 19.70401
# [DEBUG]  Perturb 5 => avg norm 19.70401
# [DEBUG]  Perturb 6 => avg norm 19.70401
# [DEBUG]  Perturb 7 => avg norm 19.70401
# [DEBUG]  Perturb 8 => avg norm 19.70401
# [DEBUG]  Perturb 9 => avg norm 19.70401
# [DEBUG]  Perturb 10 => avg norm 19.70401
# [DEBUG]  Perturb 11 => avg norm 19.70401
# [DEBUG]  Perturb 12 => avg norm 19.70401
# [DEBUG]  Perturb 13 => avg norm 19.70401
# [DEBUG]  Perturb 14 => avg norm 19.70401
# [DEBUG]  Perturb 15 => avg norm 19.70401
# [DEBUG]  Perturb 16 => avg norm 19.70401
# [DEBUG]  Perturb 17 => avg norm 19.70401
# [DEBUG]  Perturb 18 => avg norm 19.70401
# [DEBUG]  Perturb 19 => avg norm 19.70401
# [DEBUG]  Perturb 20 => avg norm 19.70401
# [DEBUG]  Perturb 21 => avg norm 19.70401
# [DEBUG]  Perturb 22 => avg norm 19.70401
# [DEBUG]  Perturb 23 => avg norm 19.70401
# [DEBUG]  Perturb 24 => avg norm 19.70401
# [DEBUG]  Perturb 25 => avg norm 19.70401
# [DEBUG]  Perturb 26 => avg norm 19.70401
# [DEBUG]  Perturb 27 => avg norm 19.70401
# [DEBUG]  Perturb 28 => avg norm 19.70401
# [DEBUG]  Perturb 29 => avg norm 19.70401
# [DEBUG]  Perturb 30 => avg norm 19.70401
# [DEBUG]  Perturb 31 => avg norm 19.70401
# [DEBUG]  Perturb 32 => avg norm 19.70401
# [DEBUG]  Perturb 33 => avg norm 19.70401
# [DEBUG]  Perturb 34 => avg norm 19.70401
# [DEBUG]  Perturb 35 => avg norm 19.70401
# [DEBUG]  Perturb 36 => avg norm 19.70401
# [DEBUG]  Perturb 37 => avg norm 19.70401
# [DEBUG]  Perturb 38 => avg norm 19.70401
# [DEBUG]  Perturb 39 => avg norm 19.70401
# [DEBUG]  Perturb 40 => avg norm 19.70401
# [DEBUG]  Perturb 41 => avg norm 19.70401
# [DEBUG]  Perturb 42 => avg norm 19.70401
# [DEBUG]  Perturb 43 => avg norm 19.70401
# [DEBUG]  Perturb 44 => avg norm 19.70401
# [DEBUG]  Perturb 45 => avg norm 19.70401
# [DEBUG]  Perturb 46 => avg norm 19.70401
# [DEBUG]  Perturb 47 => avg norm 19.70401
# [DEBUG]  Perturb 48 => avg norm 19.70401
# [DEBUG]  Perturb 49 => avg norm 19.70401
# [DEBUG]  Perturb 50 => avg norm 19.70401
# [DEBUG]  Perturb 51 => avg norm 19.70401
# [DEBUG]  Perturb 52 => avg norm 19.70401
# [DEBUG]  Perturb 53 => avg norm 19.70401
# [DEBUG]  Perturb 54 => avg norm 19.70401
# [DEBUG]  Perturb 55 => avg norm 19.70401
# [DEBUG]  Perturb 56 => avg norm 19.70401
# [DEBUG]  Perturb 57 => avg norm 19.70401
# [DEBUG]  Perturb 58 => avg norm 19.70401
# [DEBUG]  Perturb 59 => avg norm 19.70401
# [DEBUG]  Perturb 60 => avg norm 19.70401
# [DEBUG]  Perturb 61 => avg norm 19.70401
# [DEBUG]  Perturb 62 => avg norm 19.70401
# [DEBUG]  Perturb 63 => avg norm 19.70401
# [DEBUG]  Perturb 64 => avg norm 19.70401
# [DEBUG]  Perturb 65 => avg norm 19.70401
# [DEBUG]  Perturb 66 => avg norm 19.70401
# [DEBUG]  Perturb 67 => avg norm 19.70401
# [DEBUG]  Perturb 68 => avg norm 19.70401
# [DEBUG]  Perturb 69 => avg norm 19.70401
# [DEBUG]  Perturb 70 => avg norm 19.70401
# [DEBUG]  Perturb 71 => avg norm 19.70401
# [DEBUG]  Perturb 72 => avg norm 19.70401
# [DEBUG]  Perturb 73 => avg norm 19.70401
# [DEBUG]  Perturb 74 => avg norm 19.70401
# [DEBUG]  Perturb 75 => avg norm 19.70401
# [DEBUG]  Perturb 76 => avg norm 19.70401
# [DEBUG]  Perturb 77 => avg norm 19.70401
# [DEBUG]  Perturb 78 => avg norm 19.70401
# [DEBUG]  Perturb 79 => avg norm 19.70401
# [DEBUG]  Perturb 80 => avg norm 19.70401
# [DEBUG]  Perturb 81 => avg norm 19.70401
# [DEBUG]  Perturb 82 => avg norm 19.70401
# [DEBUG]  Perturb 83 => avg norm 19.70401
# [DEBUG]  Perturb 84 => avg norm 19.70401
# [DEBUG]  Perturb 85 => avg norm 19.70401
# [DEBUG]  Perturb 86 => avg norm 19.70401
# [DEBUG]  Perturb 87 => avg norm 19.70401
# [DEBUG]  Perturb 88 => avg norm 19.70401
# [DEBUG]  Perturb 89 => avg norm 19.70401
# [DEBUG]  Perturb 90 => avg norm 19.70401
# [DEBUG]  Perturb 91 => avg norm 19.70401
# [DEBUG]  Perturb 92 => avg norm 19.70401
# [DEBUG]  Perturb 93 => avg norm 19.70401
# [DEBUG]  Perturb 94 => avg norm 19.70401
# [DEBUG]  Perturb 95 => avg norm 19.70401
# [DEBUG]  Perturb 96 => avg norm 19.70401
# [DEBUG]  Perturb 97 => avg norm 19.70401
# [DEBUG]  Perturb 98 => avg norm 19.70401
# [DEBUG]  Perturb 99 => avg norm 19.70401
# [DEBUG] WeiPer average noise norm => 19.70401
# [DEBUG]  Perturb 0 => avg norm 19.70401
# [DEBUG]  Perturb 1 => avg norm 19.70401
# [DEBUG]  Perturb 2 => avg norm 19.70401
# [DEBUG]  Perturb 3 => avg norm 19.70401
# [DEBUG]  Perturb 4 => avg norm 19.70401
# [DEBUG]  Perturb 5 => avg norm 19.70401
# [DEBUG]  Perturb 6 => avg norm 19.70401
# [DEBUG]  Perturb 7 => avg norm 19.70401
# [DEBUG]  Perturb 8 => avg norm 19.70401
# [DEBUG]  Perturb 9 => avg norm 19.70401
# [DEBUG]  Perturb 10 => avg norm 19.70401
# [DEBUG]  Perturb 11 => avg norm 19.70401
# [DEBUG]  Perturb 12 => avg norm 19.70401
# [DEBUG]  Perturb 13 => avg norm 19.70401
# [DEBUG]  Perturb 14 => avg norm 19.70401
# [DEBUG]  Perturb 15 => avg norm 19.70401
# [DEBUG]  Perturb 16 => avg norm 19.70401
# [DEBUG]  Perturb 17 => avg norm 19.70401
# [DEBUG]  Perturb 18 => avg norm 19.70401
# [DEBUG]  Perturb 19 => avg norm 19.70401
# [DEBUG]  Perturb 20 => avg norm 19.70401
# [DEBUG]  Perturb 21 => avg norm 19.70401
# [DEBUG]  Perturb 22 => avg norm 19.70401
# [DEBUG]  Perturb 23 => avg norm 19.70401
# [DEBUG]  Perturb 24 => avg norm 19.70401
# [DEBUG]  Perturb 25 => avg norm 19.70401
# ...
# [DEBUG]  Perturb 33 => avg norm 20.37558
# [DEBUG]  Perturb 34 => avg norm 20.37558
# [DEBUG]  Perturb 35 => avg norm 20.37558
# [DEBUG]  Perturb 36 => avg norm 20.37558
# [DEBUG]  Perturb 37 => avg norm 20.37558
# [DEBUG]  Perturb 38 => avg norm 20.37558
# [DEBUG]  Perturb 39 => avg norm 20.37558
# [DEBUG]  Perturb 40 => avg norm 20.37558
# [DEBUG]  Perturb 41 => avg norm 20.37558
# [DEBUG]  Perturb 42 => avg norm 20.37558
# [DEBUG]  Perturb 43 => avg norm 20.37558
# [DEBUG]  Perturb 44 => avg norm 20.37558
# [DEBUG]  Perturb 45 => avg norm 20.37558
# [DEBUG]  Perturb 46 => avg norm 20.37558
# [DEBUG]  Perturb 47 => avg norm 20.37558
# [DEBUG]  Perturb 48 => avg norm 20.37558
# [DEBUG]  Perturb 49 => avg norm 20.37558
# [DEBUG]  Perturb 50 => avg norm 20.37558
# [DEBUG]  Perturb 51 => avg norm 20.37558
# [DEBUG]  Perturb 52 => avg norm 20.37558
# [DEBUG]  Perturb 53 => avg norm 20.37558
# [DEBUG]  Perturb 54 => avg norm 20.37558
# [DEBUG]  Perturb 55 => avg norm 20.37558
# [DEBUG]  Perturb 56 => avg norm 20.37558
# [DEBUG]  Perturb 57 => avg norm 20.37558
# [DEBUG]  Perturb 58 => avg norm 20.37558
# [DEBUG]  Perturb 59 => avg norm 20.37558
# [DEBUG]  Perturb 60 => avg norm 20.37558
# [DEBUG]  Perturb 61 => avg norm 20.37558
# [DEBUG]  Perturb 62 => avg norm 20.37558
# [DEBUG]  Perturb 63 => avg norm 20.37558
# [DEBUG]  Perturb 64 => avg norm 20.37558
# [DEBUG]  Perturb 65 => avg norm 20.37558
# [DEBUG]  Perturb 66 => avg norm 20.37558
# [DEBUG]  Perturb 67 => avg norm 20.37558
# [DEBUG]  Perturb 68 => avg norm 20.37558
# [DEBUG]  Perturb 69 => avg norm 20.37558
# [DEBUG]  Perturb 70 => avg norm 20.37558
# [DEBUG]  Perturb 71 => avg norm 20.37558
# [DEBUG]  Perturb 72 => avg norm 20.37558
# [DEBUG]  Perturb 73 => avg norm 20.37558
# [DEBUG]  Perturb 74 => avg norm 20.37558
# [DEBUG]  Perturb 75 => avg norm 20.37558
# [DEBUG]  Perturb 76 => avg norm 20.37558
# [DEBUG]  Perturb 77 => avg norm 20.37558
# [DEBUG]  Perturb 78 => avg norm 20.37558
# [DEBUG]  Perturb 79 => avg norm 20.37558
# [DEBUG]  Perturb 80 => avg norm 20.37558
# [DEBUG]  Perturb 81 => avg norm 20.37558
# [DEBUG]  Perturb 82 => avg norm 20.37558
# [DEBUG]  Perturb 83 => avg norm 20.37558
# [DEBUG]  Perturb 84 => avg norm 20.37558
# [DEBUG]  Perturb 85 => avg norm 20.37558
# [DEBUG]  Perturb 86 => avg norm 20.37558
# [DEBUG]  Perturb 87 => avg norm 20.37558
# [DEBUG]  Perturb 88 => avg norm 20.37558
# [DEBUG]  Perturb 89 => avg norm 20.37558
# [DEBUG]  Perturb 90 => avg norm 20.37558
# [DEBUG]  Perturb 91 => avg norm 20.37558
# [DEBUG]  Perturb 92 => avg norm 20.37558
# [DEBUG]  Perturb 93 => avg norm 20.37558
# [DEBUG]  Perturb 94 => avg norm 20.37558
# [DEBUG]  Perturb 95 => avg norm 20.37558
# [DEBUG]  Perturb 96 => avg norm 20.37558
# [DEBUG]  Perturb 97 => avg norm 20.37558
# [DEBUG]  Perturb 98 => avg norm 20.37558
# [DEBUG]  Perturb 99 => avg norm 20.37558
# [DEBUG] WeiPer average noise norm => 20.37558
# [DEBUG]  Perturb 0 => avg norm 20.37558
# [DEBUG]  Perturb 1 => avg norm 20.37558
# [DEBUG]  Perturb 2 => avg norm 20.37558
# [DEBUG]  Perturb 3 => avg norm 20.37558
# [DEBUG]  Perturb 4 => avg norm 20.37558
# [DEBUG]  Perturb 5 => avg norm 20.37558
# [DEBUG]  Perturb 6 => avg norm 20.37558
# [DEBUG]  Perturb 7 => avg norm 20.37558
# [DEBUG]  Perturb 8 => avg norm 20.37558
# [DEBUG]  Perturb 9 => avg norm 20.37558
# [DEBUG]  Perturb 10 => avg norm 20.37558
# [DEBUG]  Perturb 11 => avg norm 20.37558
# [DEBUG]  Perturb 12 => avg norm 20.37558
# [DEBUG]  Perturb 13 => avg norm 20.37558
# [DEBUG]  Perturb 14 => avg norm 20.37558
# [DEBUG]  Perturb 15 => avg norm 20.37558
# [DEBUG]  Perturb 16 => avg norm 20.37558
# [DEBUG]  Perturb 17 => avg norm 20.37558
# [DEBUG]  Perturb 18 => avg norm 20.37558
# [DEBUG]  Perturb 19 => avg norm 20.37558
# [DEBUG]  Perturb 20 => avg norm 20.37558
# [DEBUG]  Perturb 21 => avg norm 20.37558
# [DEBUG]  Perturb 22 => avg norm 20.37558
# [DEBUG]  Perturb 23 => avg norm 20.37558
# [DEBUG]  Perturb 24 => avg norm 20.37558
# [DEBUG]  Perturb 25 => avg norm 20.37558
# [DEBUG]  Perturb 26 => avg norm 20.37558
# [DEBUG]  Perturb 27 => avg norm 20.37558
# [DEBUG]  Perturb 28 => avg norm 20.37558
# [DEBUG]  Perturb 29 => avg norm 20.37558
# [DEBUG]  Perturb 30 => avg norm 20.37558
# [DEBUG]  Perturb 31 => avg norm 20.37558
# [DEBUG]  Perturb 32 => avg norm 20.37558
# [DEBUG]  Perturb 33 => avg norm 20.37558
# [DEBUG]  Perturb 34 => avg norm 20.37558
# [DEBUG]  Perturb 35 => avg norm 20.37558
# [DEBUG]  Perturb 36 => avg norm 20.37558
# [DEBUG]  Perturb 37 => avg norm 20.37558
# [DEBUG]  Perturb 38 => avg norm 20.37558
# [DEBUG]  Perturb 39 => avg norm 20.37558
# [DEBUG]  Perturb 40 => avg norm 20.37558
# [DEBUG]  Perturb 41 => avg norm 20.37558
# [DEBUG]  Perturb 42 => avg norm 20.37558
# [DEBUG]  Perturb 43 => avg norm 20.37558
# [DEBUG]  Perturb 44 => avg norm 20.37558
# [DEBUG]  Perturb 45 => avg norm 20.37558
# [DEBUG]  Perturb 46 => avg norm 20.37558
# [DEBUG]  Perturb 47 => avg norm 20.37558
# [DEBUG]  Perturb 48 => avg norm 20.37558
# [DEBUG]  Perturb 49 => avg norm 20.37558
# [DEBUG]  Perturb 50 => avg norm 20.37558
# [DEBUG]  Perturb 51 => avg norm 20.37558
# [DEBUG]  Perturb 52 => avg norm 20.37558
# [DEBUG]  Perturb 53 => avg norm 20.37558
# [DEBUG]  Perturb 54 => avg norm 20.37558
# [DEBUG]  Perturb 55 => avg norm 20.37558
# [DEBUG]  Perturb 56 => avg norm 20.37558
# [DEBUG]  Perturb 57 => avg norm 20.37558
# [DEBUG]  Perturb 58 => avg norm 20.37558
# [DEBUG]  Perturb 59 => avg norm 20.37558
# [DEBUG]  Perturb 60 => avg norm 20.37558
# [DEBUG]  Perturb 61 => avg norm 20.37558
# [DEBUG]  Perturb 62 => avg norm 20.37558
# [DEBUG]  Perturb 63 => avg norm 20.37558
# [DEBUG]  Perturb 64 => avg norm 20.37558
# [DEBUG]  Perturb 65 => avg norm 20.37558
# [DEBUG]  Perturb 66 => avg norm 20.37558
# [DEBUG]  Perturb 67 => avg norm 20.37558
# [DEBUG]  Perturb 68 => avg norm 20.37558
# [DEBUG]  Perturb 69 => avg norm 20.37558
# [DEBUG]  Perturb 70 => avg norm 20.37558
# [DEBUG]  Perturb 71 => avg norm 20.37558
# [DEBUG]  Perturb 72 => avg norm 20.37558
# [DEBUG]  Perturb 73 => avg norm 20.37558
# [DEBUG]  Perturb 74 => avg norm 20.37558
# [DEBUG]  Perturb 75 => avg norm 20.37558
# [DEBUG]  Perturb 76 => avg norm 20.37558
# [DEBUG]  Perturb 77 => avg norm 20.37558
# [DEBUG]  Perturb 78 => avg norm 20.37558
# [DEBUG]  Perturb 79 => avg norm 20.37558
# [DEBUG]  Perturb 80 => avg norm 20.37558
# [DEBUG]  Perturb 81 => avg norm 20.37558
# [DEBUG]  Perturb 82 => avg norm 20.37558
# [DEBUG]  Perturb 83 => avg norm 20.37558
# [DEBUG]  Perturb 84 => avg norm 20.37558
# [DEBUG]  Perturb 85 => avg norm 20.37558
# [DEBUG]  Perturb 86 => avg norm 20.37558
# [DEBUG]  Perturb 87 => avg norm 20.37558
# [DEBUG]  Perturb 88 => avg norm 20.37558
# [DEBUG]  Perturb 89 => avg norm 20.37558
# [DEBUG]  Perturb 90 => avg norm 20.37558
# [DEBUG]  Perturb 91 => avg norm 20.37558
# [DEBUG]  Perturb 92 => avg norm 20.37558
# [DEBUG]  Perturb 93 => avg norm 20.37558
# [DEBUG]  Perturb 94 => avg norm 20.37558
# [DEBUG]  Perturb 95 => avg norm 20.37558
# [DEBUG]  Perturb 96 => avg norm 20.37558
# [DEBUG]  Perturb 97 => avg norm 20.37558
# [DEBUG]  Perturb 98 => avg norm 20.37558
# [DEBUG]  Perturb 99 => avg norm 20.37558
# [DEBUG] WeiPer average noise norm => 20.37558
# 100%|██████████| 1/1 [00:22<00:00, 22.16s/it]
# [DEBUG]  Perturb 0 => avg norm 20.37558
# [DEBUG]  Perturb 1 => avg norm 20.37558
# [DEBUG]  Perturb 2 => avg norm 20.37558
# [DEBUG]  Perturb 3 => avg norm 20.37558
# [DEBUG]  Perturb 4 => avg norm 20.37558
# [DEBUG]  Perturb 5 => avg norm 20.37558
# [DEBUG]  Perturb 6 => avg norm 20.37558
# [DEBUG]  Perturb 7 => avg norm 20.37558
# [DEBUG]  Perturb 8 => avg norm 20.37558
# [DEBUG]  Perturb 9 => avg norm 20.37558
# [DEBUG]  Perturb 10 => avg norm 20.37558
# [DEBUG]  Perturb 11 => avg norm 20.37558
# [DEBUG]  Perturb 12 => avg norm 20.37558
# [DEBUG]  Perturb 13 => avg norm 20.37558
# [DEBUG]  Perturb 14 => avg norm 20.37558
# [DEBUG]  Perturb 15 => avg norm 20.37558
# [DEBUG]  Perturb 16 => avg norm 20.37558
# [DEBUG]  Perturb 17 => avg norm 20.37558
# [DEBUG]  Perturb 18 => avg norm 20.37558
# [DEBUG]  Perturb 19 => avg norm 20.37558
# [DEBUG]  Perturb 20 => avg norm 20.37558
# [DEBUG]  Perturb 21 => avg norm 20.37558
# [DEBUG]  Perturb 22 => avg norm 20.37558
# [DEBUG]  Perturb 23 => avg norm 20.37558
# [DEBUG]  Perturb 24 => avg norm 20.37558
# [DEBUG]  Perturb 25 => avg norm 20.37558
# [DEBUG]  Perturb 26 => avg norm 20.37558
# [DEBUG]  Perturb 27 => avg norm 20.37558
# [DEBUG]  Perturb 28 => avg norm 20.37558
# [DEBUG]  Perturb 29 => avg norm 20.37558
# [DEBUG]  Perturb 30 => avg norm 20.37558
# [DEBUG]  Perturb 31 => avg norm 20.37558
# [DEBUG]  Perturb 32 => avg norm 20.37558
# [DEBUG]  Perturb 33 => avg norm 20.37558
# [DEBUG]  Perturb 34 => avg norm 20.37558
# [DEBUG]  Perturb 35 => avg norm 20.37558
# [DEBUG]  Perturb 36 => avg norm 20.37558
# [DEBUG]  Perturb 37 => avg norm 20.37558
# [DEBUG]  Perturb 38 => avg norm 20.37558
# [DEBUG]  Perturb 39 => avg norm 20.37558
# [DEBUG]  Perturb 40 => avg norm 20.37558
# [DEBUG]  Perturb 41 => avg norm 20.37558
# [DEBUG]  Perturb 42 => avg norm 20.37558
# [DEBUG]  Perturb 43 => avg norm 20.37558
# [DEBUG]  Perturb 44 => avg norm 20.37558
# [DEBUG]  Perturb 45 => avg norm 20.37558
# [DEBUG]  Perturb 46 => avg norm 20.37558
# [DEBUG]  Perturb 47 => avg norm 20.37558
# [DEBUG]  Perturb 48 => avg norm 20.37558
# [DEBUG]  Perturb 49 => avg norm 20.37558
# [DEBUG]  Perturb 50 => avg norm 20.37558
# [DEBUG]  Perturb 51 => avg norm 20.37558
# [DEBUG]  Perturb 52 => avg norm 20.37558
# [DEBUG]  Perturb 53 => avg norm 20.37558
# [DEBUG]  Perturb 54 => avg norm 20.37558
# [DEBUG]  Perturb 55 => avg norm 20.37558
# [DEBUG]  Perturb 56 => avg norm 20.37558
# [DEBUG]  Perturb 57 => avg norm 20.37558
# [DEBUG]  Perturb 58 => avg norm 20.37558
# [DEBUG]  Perturb 59 => avg norm 20.37558
# [DEBUG]  Perturb 60 => avg norm 20.37558
# [DEBUG]  Perturb 61 => avg norm 20.37558
# [DEBUG]  Perturb 62 => avg norm 20.37558
# [DEBUG]  Perturb 63 => avg norm 20.37558
# [DEBUG]  Perturb 64 => avg norm 20.37558
# [DEBUG]  Perturb 65 => avg norm 20.37558
# [DEBUG]  Perturb 66 => avg norm 20.37558
# [DEBUG]  Perturb 67 => avg norm 20.37558
# [DEBUG]  Perturb 68 => avg norm 20.37558
# [DEBUG]  Perturb 69 => avg norm 20.37558
# [DEBUG]  Perturb 70 => avg norm 20.37558
# [DEBUG]  Perturb 71 => avg norm 20.37558
# [DEBUG]  Perturb 72 => avg norm 20.37558
# [DEBUG]  Perturb 73 => avg norm 20.37558
# [DEBUG]  Perturb 74 => avg norm 20.37558
# [DEBUG]  Perturb 75 => avg norm 20.37558
# [DEBUG]  Perturb 76 => avg norm 20.37558
# [DEBUG]  Perturb 77 => avg norm 20.37558
# [DEBUG]  Perturb 78 => avg norm 20.37558
# [DEBUG]  Perturb 79 => avg norm 20.37558
# [DEBUG]  Perturb 80 => avg norm 20.37558
# [DEBUG]  Perturb 81 => avg norm 20.37558
# [DEBUG]  Perturb 82 => avg norm 20.37558
# [DEBUG]  Perturb 83 => avg norm 20.37558
# [DEBUG]  Perturb 84 => avg norm 20.37558
# [DEBUG]  Perturb 85 => avg norm 20.37558
# [DEBUG]  Perturb 86 => avg norm 20.37558
# [DEBUG]  Perturb 87 => avg norm 20.37558
# [DEBUG]  Perturb 88 => avg norm 20.37558
# [DEBUG]  Perturb 89 => avg norm 20.37558
# [DEBUG]  Perturb 90 => avg norm 20.37558
# [DEBUG]  Perturb 91 => avg norm 20.37558
# [DEBUG]  Perturb 92 => avg norm 20.37558
# [DEBUG]  Perturb 93 => avg norm 20.37558
# [DEBUG]  Perturb 94 => avg norm 20.37558
# [DEBUG]  Perturb 95 => avg norm 20.37558
# [DEBUG]  Perturb 96 => avg norm 20.37558
# [DEBUG]  Perturb 97 => avg norm 20.37558
# [DEBUG]  Perturb 98 => avg norm 20.37558
# [DEBUG]  Perturb 99 => avg norm 20.37558
# [DEBUG] WeiPer average noise norm => 20.37558
# [DEBUG]  Perturb 0 => avg norm 20.37558
# [DEBUG]  Perturb 1 => avg norm 20.37558
# [DEBUG]  Perturb 2 => avg norm 20.37558
# [DEBUG]  Perturb 3 => avg norm 20.37558
# [DEBUG]  Perturb 4 => avg norm 20.37558
# [DEBUG]  Perturb 5 => avg norm 20.37558
# [DEBUG]  Perturb 6 => avg norm 20.37558
# [DEBUG]  Perturb 7 => avg norm 20.37558
# [DEBUG]  Perturb 8 => avg norm 20.37558
# [DEBUG]  Perturb 9 => avg norm 20.37558
# [DEBUG]  Perturb 10 => avg norm 20.37558
# [DEBUG]  Perturb 11 => avg norm 20.37558
# [DEBUG]  Perturb 12 => avg norm 20.37558
# [DEBUG]  Perturb 13 => avg norm 20.37558
# [DEBUG]  Perturb 14 => avg norm 20.37558
# [DEBUG]  Perturb 15 => avg norm 20.37558
# [DEBUG]  Perturb 16 => avg norm 20.37558
# [DEBUG]  Perturb 17 => avg norm 20.37558
# [DEBUG]  Perturb 18 => avg norm 20.37558
# [DEBUG]  Perturb 19 => avg norm 20.37558
# [DEBUG]  Perturb 20 => avg norm 20.37558
# [DEBUG]  Perturb 21 => avg norm 20.37558
# [DEBUG]  Perturb 22 => avg norm 20.37558
# [DEBUG]  Perturb 23 => avg norm 20.37558
# [DEBUG]  Perturb 24 => avg norm 20.37558
# [DEBUG]  Perturb 25 => avg norm 20.37558
# [DEBUG]  Perturb 26 => avg norm 20.37558
# [DEBUG]  Perturb 27 => avg norm 20.37558
# [DEBUG]  Perturb 28 => avg norm 20.37558
# [DEBUG]  Perturb 29 => avg norm 20.37558
# [DEBUG]  Perturb 30 => avg norm 20.37558
# [DEBUG]  Perturb 31 => avg norm 20.37558
# [DEBUG]  Perturb 32 => avg norm 20.37558
# [DEBUG]  Perturb 33 => avg norm 20.37558
# [DEBUG]  Perturb 34 => avg norm 20.37558
# [DEBUG]  Perturb 35 => avg norm 20.37558
# [DEBUG]  Perturb 36 => avg norm 20.37558
# [DEBUG]  Perturb 37 => avg norm 20.37558
# [DEBUG]  Perturb 38 => avg norm 20.37558
# [DEBUG]  Perturb 39 => avg norm 20.37558
# [DEBUG]  Perturb 40 => avg norm 20.37558
# [DEBUG]  Perturb 41 => avg norm 20.37558
# [DEBUG]  Perturb 42 => avg norm 20.37558
# [DEBUG]  Perturb 43 => avg norm 20.37558
# [DEBUG]  Perturb 44 => avg norm 20.37558
# [DEBUG]  Perturb 45 => avg norm 20.37558
# [DEBUG]  Perturb 46 => avg norm 20.37558
# [DEBUG]  Perturb 47 => avg norm 20.37558
# [DEBUG]  Perturb 48 => avg norm 20.37558
# [DEBUG]  Perturb 49 => avg norm 20.37558
# [DEBUG]  Perturb 50 => avg norm 20.37558
# [DEBUG]  Perturb 51 => avg norm 20.37558
# [DEBUG]  Perturb 52 => avg norm 20.37558
# [DEBUG]  Perturb 53 => avg norm 20.37558
# [DEBUG]  Perturb 54 => avg norm 20.37558
# [DEBUG]  Perturb 55 => avg norm 20.37558
# [DEBUG]  Perturb 56 => avg norm 20.37558
# [DEBUG]  Perturb 57 => avg norm 20.37558
# [DEBUG]  Perturb 58 => avg norm 20.37558
# [DEBUG]  Perturb 59 => avg norm 20.37558
# [DEBUG]  Perturb 60 => avg norm 20.37558
# [DEBUG]  Perturb 61 => avg norm 20.37558
# [DEBUG]  Perturb 62 => avg norm 20.37558
# [DEBUG]  Perturb 63 => avg norm 20.37558
# [DEBUG]  Perturb 64 => avg norm 20.37558
# [DEBUG]  Perturb 65 => avg norm 20.37558
# [DEBUG]  Perturb 66 => avg norm 20.37558
# [DEBUG]  Perturb 67 => avg norm 20.37558
# [DEBUG]  Perturb 68 => avg norm 20.37558
# [DEBUG]  Perturb 69 => avg norm 20.37558
# [DEBUG]  Perturb 70 => avg norm 20.37558
# [DEBUG]  Perturb 71 => avg norm 20.37558
# [DEBUG]  Perturb 72 => avg norm 20.37558
# [DEBUG]  Perturb 73 => avg norm 20.37558
# [DEBUG]  Perturb 74 => avg norm 20.37558
# [DEBUG]  Perturb 75 => avg norm 20.37558
# [DEBUG]  Perturb 76 => avg norm 20.37558
# [DEBUG]  Perturb 77 => avg norm 20.37558
# [DEBUG]  Perturb 78 => avg norm 20.37558
# [DEBUG]  Perturb 79 => avg norm 20.37558
# [DEBUG]  Perturb 80 => avg norm 20.37558
# [DEBUG]  Perturb 81 => avg norm 20.37558
# [DEBUG]  Perturb 82 => avg norm 20.37558
# [DEBUG]  Perturb 83 => avg norm 20.37558
# [DEBUG]  Perturb 84 => avg norm 20.37558
# [DEBUG]  Perturb 85 => avg norm 20.37558
# [DEBUG]  Perturb 86 => avg norm 20.37558
# [DEBUG]  Perturb 87 => avg norm 20.37558
# [DEBUG]  Perturb 88 => avg norm 20.37558
# [DEBUG]  Perturb 89 => avg norm 20.37558
# [DEBUG]  Perturb 90 => avg norm 20.37558
# [DEBUG]  Perturb 91 => avg norm 20.37558
# [DEBUG]  Perturb 92 => avg norm 20.37558
# [DEBUG]  Perturb 93 => avg norm 20.37558
# [DEBUG]  Perturb 94 => avg norm 20.37558
# [DEBUG]  Perturb 95 => avg norm 20.37558
# [DEBUG]  Perturb 96 => avg norm 20.37558
# [DEBUG]  Perturb 97 => avg norm 20.37558
# [DEBUG]  Perturb 98 => avg norm 20.37558
# [DEBUG]  Perturb 99 => avg norm 20.37558
# [DEBUG] WeiPer average noise norm => 20.37558
# Computing metrics on cifar100 dataset...
# FPR@95: 41.02, AUROC: 89.15 AUPR_IN: 87.34, AUPR_OUT: 89.33
# ──────────────────────────────────────────────────────────────────────
#
# Computing mean metrics...
# FPR@95: 41.02, AUROC: 89.15 AUPR_IN: 87.34, AUPR_OUT: 89.33
# ──────────────────────────────────────────────────────────────────────
# ID Acc Eval: 100%|██████████| 1/1 [00:44<00:00, 44.49s/it]
#           FPR@95  AUROC  AUPR_IN  AUPR_OUT   ACC
# cifar100   41.02  89.15    87.34     89.33 95.32
# nearood    41.02  89.15    87.34     89.33 95.32
#              FPR@95      AUROC    AUPR_IN   AUPR_OUT        ACC
# cifar100  44.355556  88.174422  86.098474  88.271536  95.059259
# nearood   44.355556  88.174422  86.098474  88.271536  95.059259
