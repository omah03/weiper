# %% [markdown]
# ## WeiPer on OpenOOD
# Set `dataset` to `cifar10` or `cifar100`
# and `postprocessor_name` to `weiper_density` to test WeiPer on CIFAR
# or `dataset`to `imagenet` to test WeiPer on ImageNet using ResNet50.
#
# Our method includes random perturbations and produces different results each time. To reduce the noise, set `iterations` to `5` or higher.
#
# ## Hyperparameters
# The hyperparameters can be set and found here:
# `./OpenOOD/configs/postprocessors/weiper_kldiv.yml`

# %%
# %load_ext autoreload
# %autoreload 2

from openood.networks import ResNet18_32x32
import torch
from openood.evaluation_api import Evaluator
from openood.preprocessors import BasePreprocessor
from tqdm import tqdm

from openood.networks import ResNet50
from torchvision.models import ResNet50_Weights
from torch.hub import load_state_dict_from_url

# %%
dataset = "cifar10"
models = [ResNet18_32x32(num_classes=100 if dataset=="cifar100" else 10)
          for _ in range(3)]
[model.load_state_dict(
    torch.load(f'./OpenOOD/results/{dataset}_resnet18_32x32_base_e100_lr0.1_default/s{i}/best.ckpt')
) for i,model in enumerate(models)]
# Out:
# /tmp/ipykernel_1736765/2904996973.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(f'./OpenOOD/results/{dataset}_resnet18_32x32_base_e100_lr0.1_default/s{i}/best.ckpt')
# [<All keys matched successfully>,
#  <All keys matched successfully>,
#  <All keys matched successfully>]

# %%
from functools import wraps

def batch_processing_decorator(batch_size):
    def decorator(forward_fn):
        @wraps(forward_fn)
        def wrapped_forward(x, *args, **kwargs):
            # Split the input tensor into smaller batches
            batched_input = torch.split(x, batch_size, dim=0)
            
            outputs = []
            # Instead of a single features list, we must handle the possibility
            # that we get a single tensor or a list of tensors for features.
            # We'll detect this on the first batch and then process accordingly.

            # These accumulators will be set after processing the first batch.
            # If features is a single tensor:
            #   features_single will hold the concatenation of these tensors
            # If features is a list of tensors:
            #   features_list_acc will be a list of lists, one for each layer.
            features_single = None
            features_list_acc = None
            is_feature_list = False

            first_batch = True

            for batch in tqdm(batched_input, disable=True):
                output = forward_fn(batch, *args, **kwargs)
                if isinstance(output, tuple):
                    # output can be (logits, feature) or (logits, feature_list)
                    logits = output[0]
                    feat = output[1]

                    outputs.append(logits.cpu())

                    if first_batch:
                        # Detect if feat is a tensor or a list
                        if isinstance(feat, torch.Tensor):
                            # single feature tensor
                            features_single = [feat.cpu()]
                            is_feature_list = False
                            print("[DEBUG] Detected single feature tensor in first batch")
                        elif isinstance(feat, list):
                            # list of features
                            is_feature_list = True
                            features_list_acc = [[] for _ in feat]
                            for i, f in enumerate(feat):
                                features_list_acc[i].append(f.cpu())
                            print("[DEBUG] Detected feature_list (multiple layers) in first batch")
                        else:
                            raise TypeError("[DEBUG] Unknown feature type returned by model.")
                        first_batch = False
                    else:
                        # subsequent batches
                        if is_feature_list:
                            # feat should be a list of tensors
                            if not isinstance(feat, list):
                                raise TypeError("[DEBUG] Inconsistent return type: expected list of tensors.")
                            if len(feat) != len(features_list_acc):
                                raise ValueError("[DEBUG] Layer count mismatch between batches.")
                            for i, f in enumerate(feat):
                                features_list_acc[i].append(f.cpu())
                        else:
                            # single tensor case
                            if not isinstance(feat, torch.Tensor):
                                raise TypeError("[DEBUG] Inconsistent return type: expected single tensor.")
                            features_single.append(feat.cpu())

                else:
                    # output is just logits
                    outputs.append(output.cpu())
                    # No features here
                    if first_batch:
                        # This would mean no features at all, which is not what we expect for OOD scoring.
                        # But let's just handle it gracefully.
                        features_single = None
                        features_list_acc = None
                        is_feature_list = False
                        first_batch = False

            final_output = torch.cat(outputs, dim=0)
            if is_feature_list:
                # concatenate each layer separately
                final_features = [torch.cat(layer_feats, dim=0) for layer_feats in features_list_acc]
                return final_output, final_features
            else:
                if features_single is not None:
                    final_features = torch.cat(features_single, dim=0)
                    return final_output, final_features
                else:
                    # No features returned at all scenario
                    return final_output
        return wrapped_forward
    return decorator

if dataset == 'imagenet':
    net = ResNet50()
    weights = ResNet50_Weights.IMAGENET1K_V1
    net.load_state_dict(load_state_dict_from_url(weights.url))
    
    net.forward =  batch_processing_decorator(batch_size=200)(net.forward)
    models = [net]
else:
    for m in models:
        m.forward = batch_processing_decorator(batch_size=200)(m.forward)

# %%
metrics = None
iterations = 1
for i in tqdm(range(iterations), disable=True):
    for j, model in enumerate(models):
        model.cuda()
        model.eval()

        evaluator = Evaluator(
            model, 
            id_name=dataset,
            data_root="./data",
            config_root="./OpenOOD/configs/",
            preprocessor=None, 
            postprocessor_name='weiper_kldiv', 
            batch_size=int(1e4),
            verbose=True, 
            APS_mode=False,
            num_workers=0,
        )
        evaluator.postprocessor.n_repeats = (
            100 if dataset == "cifar10" else 100
        )
        evaluator.eval_ood()
        if i == 0 and j == 0:
            metrics = evaluator.metrics["ood"]
            print(evaluator.postprocessor.get_hyperparam())
        else:
            metrics += evaluator.metrics["ood"] 
metrics/(len(models)*iterations)
# Out:
# [DEBUG] Entering WeiPerKLDivPostprocessor.setup
# [DEBUG] layer_names received: [3, 4]
# [DEBUG] layers_to_process: [3, 4]
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# [DEBUG] Detected feature_list (multiple layers) in first batch
# Calculate perturbed logits...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 8
#       5 model.cuda()
#       6 model.eval()
# ----> 8 evaluator = Evaluator(
#       9     model,
#      10     id_name=dataset,
#      11     data_root="./data",
#      12     config_root="./OpenOOD/configs/",
#      13     preprocessor=None,
#      14     postprocessor_name='weiper_kldiv',
#      15     batch_size=int(1e4),
#      16     verbose=True,
#      17     APS_mode=False,
#      18     num_workers=0,
#      19 )
#      20 evaluator.postprocessor.n_repeats = (
#      21     100 if dataset == "cifar10" else 100
#      22 )
#      23 evaluator.eval_ood()
#
# File /media/dc-04-vol03/omar/Bachelor/weiper/Weiper/OpenOOD/openood/evaluation_api/evaluator.py:141, in Evaluator.__init__(self, net, id_name, data_root, config_root, preprocessor, postprocessor_name, postprocessor, batch_size, shuffle, num_workers, cached_dir, use_cache, APS_mode, verbose, **postpc_kwargs)
#     131     postprocessor.setup(
#     132         net,
#     133         dataloader_dict["id"],
#    (...)
#     137         **postpc_kwargs,
#     138     )
#     139 else:
#     140     # start_time = time.time()
# --> 141     postprocessor.setup(net, dataloader_dict["id"], dataloader_dict["ood"])
#     142     # end_time = time.time()
#     143     # print(f"Setup time: {end_time - start_time}")
#     145 self.id_name = id_name
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /media/dc-04-vol03/omar/Bachelor/weiper/Weiper/OpenOOD/openood/postprocessors/weiper_kldiv_postprocessor.py:168, in WeiPerKLDivPostprocessor.setup(self, net, id_loader_dict, ood_loader_dict, id_name, valid_num, layer_names, aps, use_cache, hyperparameter_search, latents_loader, **kwargs)
#     160 latents = self.flatten_features(feature_list[layer_idx])
#     161 is_penultimate = (layer_idx == 4)
#     163 (
#     164     train_densities,
#     165     train_densities_weiper,
#     166     updated_min_max,
#     167     updated_W_tilde,
# --> 168 ) = compute_train_densities_for_layer(latents, is_penultimate)
#     170 if layer_accumulators[key]['dens'] is None:
#     171     layer_accumulators[key]['dens'] = train_densities
#
# File /media/dc-04-vol03/omar/Bachelor/weiper/Weiper/OpenOOD/openood/postprocessors/weiper_kldiv_postprocessor.py:128, in WeiPerKLDivPostprocessor.setup.<locals>.compute_train_densities_for_layer(latents, is_penultimate)
#     113     return calculate_WeiPerKLDiv_score(
#     114         net,
#     115         latents,
#    (...)
#     125         train_min_max=self.train_min_max
#     126     )
#     127 else:
# --> 128     return calculate_WeiPerKLDiv_score(
#     129         net,
#     130         latents,
#     131         lambda_1=self.lambda_1,
#     132         lambda_2=self.lambda_2,
#     133         n_bins=self.n_bins,
#     134         n_repeats=1,  # minimal perturbation
#     135         smoothing=self.smoothing,
#     136         smoothing_perturbed=self.smoothing_perturbed,
#     137         perturbation_distance=0.0,  # no perturbation
#     138         device=device,
#     139         train_min_max=None,
#     140         W_tilde=None,
#     141     )
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /media/dc-04-vol03/omar/Bachelor/weiper/Weiper/OpenOOD/openood/postprocessors/weiper_kldiv/utils.py:377, in calculate_WeiPerKLDiv_score(model, latents, n_bins, perturbation_distance, n_repeats, smoothing, smoothing_perturbed, epsilon, epsilon_noise, lambda_1, lambda_2, symmetric, device, verbose, ablation_noise_only, train_min_max, train_densities, perturbed_fc, **params)
#     375 if verbose:
#     376     print("Calculate perturbed logits...")
# --> 377 latents_weiper, W_tilde = calculate_weiper_space(
#     378     model,
#     379     latents,
#     380     perturbed_fc=perturbed_fc,
#     381     device="cpu",
#     382     perturbation_distance=perturbation_distance,
#     383     n_repeats=n_repeats,
#     384     noise_proportional=True,
#     385     constant_length=True,
#     386     batch_size=200,
#     387     ablation_noise_only=ablation_noise_only,
#     388 )
#     390 if verbose:
#     391     print("Evaluate density...")
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /media/dc-04-vol03/omar/Bachelor/weiper/Weiper/OpenOOD/openood/postprocessors/weiper_kldiv/utils.py:219, in calculate_weiper_space(model, latents, perturbed_fc, device, perturbation_distance, n_repeats, noise_proportional, constant_length, batch_size, ablation_noise_only)
#     215 if perturbed_fc is None:
#     216     perturbed_fc = build_lin()
#     218 weiper_logits = torch.cat(
# --> 219     [perturbed_fc(x.to(device)).cpu() for x in latents.split(batch_size)], dim=0
#     220 )
#     222 return weiper_logits, perturbed_fc
#
# File /media/dc-04-vol03/omar/Bachelor/weiper/Weiper/OpenOOD/openood/postprocessors/weiper_kldiv/utils.py:219, in <listcomp>(.0)
#     215 if perturbed_fc is None:
#     216     perturbed_fc = build_lin()
#     218 weiper_logits = torch.cat(
# --> 219     [perturbed_fc(x.to(device)).cpu() for x in latents.split(batch_size)], dim=0
#     220 )
#     222 return weiper_logits, perturbed_fc
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/weiper_env/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (200x16384 and 512x10)
